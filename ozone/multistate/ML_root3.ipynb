# %%
# For data generation
import sys
# !{sys.executable} -m pip install matplotlib --upgrade
import shutil
import os
import numpy as np
from glob import glob
import re
import pandas as pd
import pickle
#random
from time import perf_counter

# sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,root_mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV


#Plotting
import seaborn as sns
sns.set_style()
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 200

import warnings
# warnings.filterwarnings("ignore", category=np.DeprecationWarning) 


from tqdm.auto import tqdm
# from tqdm.notebook import tqdm_notebook as tqdm

# %%
with open(os.path.join(os.path.expanduser('~'),'DDCASPT2/drop.txt'),'r') as d:
    dropfeat = [i.replace('\n','') for i in d.readlines()]

# %%
# with open('test_ind.pickle', 'rb') as handle:
#     test_ind = pickle.load(handle)

# with open('train_ind.pickle', 'rb') as handle:
#     train_ind = pickle.load(handle)

with open('big_test_ind.pickle', 'rb') as handle:
    test_ind = pickle.load(handle)

with open('big_train_ind.pickle', 'rb') as handle:
    train_ind = pickle.load(handle)
# train_ind = train_ind[train_ind>=110]
# test_ind = test_ind[test_ind>=110]    
train_ind = list(map(float,train_ind))
test_ind = list(map(float,test_ind))
train_ind, test_ind = train_test_split(train_ind+test_ind,test_size=0.3, random_state=42)
print(len(train_ind),len(test_ind))
# Out:
# 212 92

# %%
len(train_ind+test_ind)
# Out:
# 304

# %%
rename = {'h$_{qq}^{0}$':'h$_{q}$',
'$(F_{q})_{0}$':'$F_{q}$',
'$(F_{q}^{\\text{SCF}})_{0}$':'$F_{q}^{\\text{SCF}}$',
'$(\\eta_{q})_{0}$':'$\\eta_{q}$',
'$(\\omega_{q})_{0}$':'$\\omega_{q}$',
'$(\\eta_{s})_{0}$':'$\\eta_{s}$',
'h$_{ss}^{0}$':'h$_{s}$',
'$(F_{s}^{\\text{SCF}})_{0}$':'$F_{s}^{\\text{SCF}}$',
'$(F_{s})_{0}$':'$F_{s}$',
'$(\\omega_{s})_{0}$':'$\\omega_{s}$',
'$(\\langle ss \\vert ss \\rangle)_{0}$':"$\\langle ss \\vert ss \\rangle$",
'$(\\langle qq \\vert qq \\rangle)_{0}$':"$\langle qq \\vert qq \\rangle$",
'h$_{pp}^{0}$': '(h$_{p}$)$_{0}$',
'h$_{pp}^{1}$': '(h$_{p}$)$_{1}$',
'h$_{pp}^{2}$': '(h$_{p}$)$_{2}$',
'h$_{pp}^{3}$': '(h$_{p}$)$_{3}$',
'h$_{rr}^{0}$': '(h$_{r}$)$_{0}$',
'h$_{rr}^{1}$': '(h$_{r}$)$_{1}$',
'h$_{rr}^{2}$': '(h$_{r}$)$_{2}$',
'h$_{rr}^{3}$': '(h$_{r}$)$_{3}$',
'h$_{pq}^{0}$':'(h$_{pq}$)$_{0}$',
'h$_{pq}^{1}$':'(h$_{pq}$)$_{1}$',
'h$_{pq}^{2}$':'(h$_{pq}$)$_{2}$',
'h$_{pq}^{3}$':'(h$_{pq}$)$_{3}$',
'h$_{pr}^{0}$':'(h$_{pr}$)$_{0}$',
'h$_{pr}^{1}$':'(h$_{pr}$)$_{1}$',
'h$_{pr}^{2}$':'(h$_{pr}$)$_{2}$',
'h$_{pr}^{3}$':'(h$_{pr}$)$_{3}$',
'h$_{rs}^{0}$':'(h$_{rs}$)$_{0}$',
'h$_{rs}^{1}$':'(h$_{rs}$)$_{1}$',
'h$_{rs}^{2}$':'(h$_{rs}$)$_{2}$',
'h$_{rs}^{3}$':'(h$_{rs}$)$_{3}$',
'typ_0':'$type_0$',
'typ_1':'$type_1$',
'typ_2':'$type_2$',
'typ_3':'$type_3$'}

# %%
def grab_state_data(state,dropfeat):
    train = []
    test = []
    
    
    
    recover_train = []
    recover_test = []
    
    traincnt = 0
    testcnt = 0
    # TZP: 1e-5
    # DZP: 1e-5
    # mb: 1e-3
    for i in sorted(glob('ANO-RCC-VTZP/')):
        for j in glob(os.path.join(i,'ozone_*')):
            for k in train_ind:
                if f"{k:.2f}" in j:
                    traindf = pd.read_csv(os.path.join(j,os.path.basename(j)+f'_{state}.csv'),index_col=0)
                    # traindf = traindf[traindf['Pair_Energies'].abs()>=1e-5]
                    train.append(traindf)
                    recover_train.append((i,f"{k:.2f}",traincnt,len(traindf)))
                    traincnt+=1
                    
            for l in test_ind:
                if f"{l:.2f}" in j:
                    testdf = pd.read_csv(os.path.join(j,os.path.basename(j)+f'_{state}.csv'),index_col=0)
                    # testdf = testdf[testdf['Pair_Energies'].abs()>=1e-5]
                    test.append(testdf)                    
                    recover_test.append((i,f"{l:.2f}",testcnt,len(testdf)))
                    testcnt+=1
    
    dropfeat = [a for a in dropfeat if a not in ['D$_{qs}$', 'F$_{qs}$', 'FA$_{qs}$', 'FI$_{qs}$']]
    train_df = pd.concat(train).drop(columns=dropfeat).rename(columns=rename)
    test_df = pd.concat(test).drop(columns=dropfeat).rename(columns=rename)                    

    return train_df, test_df, recover_train, recover_test

# %%
# train_df, test_df, recover_train, recover_test = grab_state_data(1,dropfeat)
# train_df, test_df, recover_train, recover_test = grab_state_data(2,dropfeat)
train_df, test_df, recover_train, recover_test = grab_state_data(3,dropfeat)

# train_df_1, test_df_1, recover_train_1, recover_test_1 = grab_state_data(1,dropfeat)
# train_df_2, test_df_2, recover_train_2, recover_test_2 = grab_state_data(2,dropfeat)
# train_df_3, test_df_3, recover_train_3, recover_test_3 = grab_state_data(3,dropfeat)

# %%
X_train = train_df.drop(columns=['Pair_Energies']).values
X_test = test_df.drop(columns=['Pair_Energies']).values

y_train = train_df['Pair_Energies'].values
y_test = test_df['Pair_Energies'].values

# %%
X_train.shape
# Out:
# (33072, 102)

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from xgboost import XGBRegressor

# kwargs = dict(pd.read_excel("ozone_VTZP_MS_3_70_30_params.xlsx").values)
# model=XGBRegressor(**kwargs)
# model.fit(X_train,y_train)
# y_pred_train=model.predict(X_train)
# y_pred_test=model.predict(X_test)
# print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
# print(f"RMSE (mEh): {root_mean_squared_error(y_train,y_pred_train)*1e3:.4f},{root_mean_squared_error(y_test,y_pred_test)*1e3:.4f}")

params = {'max_depth': [1, 10, 100],
          'n_estimators': [100, 500, 1000],
          'reg_lambda': [1e-6, 1e-3,1e-1],
          'reg_alpha': [1e-6, 1e-3,1e-1]}

model = XGBRegressor()
grid = GridSearchCV(estimator=model, 
                   param_grid=params,
                   scoring='r2', 
                   verbose=100,n_jobs=12).fit(X_train,y_train)


model=grid.best_estimator_
y_pred_train=model.predict(X_train)
y_pred_test=model.predict(X_test)
print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
print(f"RMSE (mEh): {root_mean_squared_error(y_train,y_pred_train)*1e3:.4f},{root_mean_squared_error(y_test,y_pred_test)*1e3:.4f}")
pd.DataFrame.from_dict(model.get_params(),orient='index').dropna().to_excel("ozone_VTZP_MS_3_70_30_params.xlsx")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 2/5; 3/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 2/5; 3/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.339 total time=   0.4s
# [CV 3/5; 3/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 3/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.375 total time=   0.4s
# [CV 5/5; 5/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 5/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.371 total time=   0.4s
# [CV 2/5; 7/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 7/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.333 total time=   0.4s
# [CV 2/5; 9/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 2/5; 9/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.333 total time=   0.4s
# [CV 1/5; 11/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 1/5; 11/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.544 total time=   0.9s
# [CV 4/5; 12/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1
# [CV 4/5; 12/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1;, score=0.556 total time=   1.0s
# [CV 5/5; 14/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 14/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.559 total time=   0.9s
# [CV 5/5; 15/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 5/5; 15/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.559 total time=   1.0s
# [CV 2/5; 18/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 2/5; 18/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.510 total time=   0.9s
# [CV 1/5; 19/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 19/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.617 total time=   1.7s
# [CV 3/5; 21/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 21/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.628 total time=   1.7s
# [CV 4/5; 22/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 4/5; 22/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.626 total time=   1.7s
# [CV 4/5; 24/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 24/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.625 total time=   1.7s
# [CV 4/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 4/5; 26/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.609 total time=   1.7s
# [CV 5/5; 27/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 5/5; 27/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.609 total time=   1.8s
# [CV 2/5; 30/81] START max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 2/5; 30/81] END max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.993 total time=   1.7s
# [CV 3/5; 31/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 3/5; 31/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.995 total time=   1.5s
# [CV 4/5; 33/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 33/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   1.5s
# [CV 3/5; 35/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 3/5; 35/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.984 total time=   1.3s
# [CV 1/5; 37/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 37/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.990 total time=   2.3s
# [CV 3/5; 39/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 39/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1;, score=0.995 total time=   2.1s
# [CV 2/5; 41/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 2/5; 41/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.993 total time=   2.2s
# [CV 4/5; 42/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 42/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   1.9s
# [CV 4/5; 44/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001
# [CV 4/5; 44/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001;, score=0.982 total time=   1.7s
# [CV 2/5; 46/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 2/5; 46/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.993 total time=   2.9s
# [CV 3/5; 48/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 48/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.995 total time=   2.7s
# [CV 5/5; 49/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 49/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.991 total time=   2.8s
# [CV 4/5; 51/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 51/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   2.6s
# [CV 3/5; 53/81] START max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 3/5; 53/81] END max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.984 total time=   2.5s
# [CV 1/5; 55/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 55/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.989 total time=   1.9s
# [CV 5/5; 56/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 56/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001;, score=0.989 total time=   2.9s
# [CV 4/5; 58/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 4/5; 58/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.991 total time=   3.5s
# [CV 4/5; 61/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 4/5; 61/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.988 total time=   2.9s
# [CV 1/5; 64/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 64/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.989 total time=   3.4s
# [CV 3/5; 66/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 66/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1;, score=0.995 total time=   2.9s
# [CV 2/5; 68/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 2/5; 68/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.993 total time=   2.7s
# [CV 4/5; 69/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 69/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.992 total time=   2.5s
# [CV 5/5; 71/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001
# [CV 5/5; 71/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001;, score=0.986 total time=   2.4s
# [CV 3/5; 73/81] START max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 3/5; 73/81] END max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.995 total time=   4.0s
# [CV 4/5; 1/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 4/5; 1/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.372 total time=   0.5s
# [CV 1/5; 4/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 4/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.360 total time=   0.4s
# [CV 1/5; 6/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 1/5; 6/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.360 total time=   0.4s
# [CV 3/5; 7/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 3/5; 7/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.367 total time=   0.4s
# [CV 3/5; 9/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 9/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.366 total time=   0.4s
# [CV 4/5; 11/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 4/5; 11/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.556 total time=   0.9s
# [CV 5/5; 12/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1
# [CV 5/5; 12/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1;, score=0.559 total time=   1.0s
# [CV 2/5; 15/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 2/5; 15/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.525 total time=   1.0s
# [CV 1/5; 16/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 1/5; 16/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.529 total time=   1.0s
# [CV 3/5; 18/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 18/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.542 total time=   1.0s
# [CV 4/5; 19/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 4/5; 19/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.626 total time=   1.7s
# [CV 4/5; 21/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 4/5; 21/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.626 total time=   1.7s
# [CV 3/5; 23/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001
# [CV 3/5; 23/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001;, score=0.627 total time=   1.7s
# [CV 5/5; 24/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 5/5; 24/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.629 total time=   1.7s
# [CV 5/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 5/5; 26/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.609 total time=   1.7s
# [CV 1/5; 28/81] START max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 28/81] END max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.990 total time=   1.4s
# [CV 5/5; 29/81] START max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 29/81] END max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001;, score=0.991 total time=   1.7s
# [CV 1/5; 31/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 31/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.992 total time=   1.5s
# [CV 3/5; 33/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 3/5; 33/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.995 total time=   1.5s
# [CV 5/5; 34/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 5/5; 34/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.983 total time=   1.3s
# [CV 4/5; 36/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 36/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.982 total time=   1.4s
# [CV 5/5; 38/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 38/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.991 total time=   2.1s
# [CV 1/5; 40/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 40/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.992 total time=   2.2s
# [CV 3/5; 42/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 3/5; 42/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.995 total time=   3.2s
# [CV 3/5; 45/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 45/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.985 total time=   3.2s
# [CV 1/5; 48/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 1/5; 48/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.992 total time=   4.8s
# [CV 2/5; 51/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 2/5; 51/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   4.5s
# [CV 5/5; 53/81] START max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 5/5; 53/81] END max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.983 total time=   4.5s
# [CV 2/5; 57/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 2/5; 57/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.993 total time=   4.0s
# [CV 5/5; 59/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 59/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.991 total time=   2.3s
# [CV 1/5; 62/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 1/5; 62/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.989 total time=   2.0s
# [CV 3/5; 63/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 63/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.989 total time=   2.6s
# [CV 4/5; 65/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 4/5; 65/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.991 total time=   3.0s
# [CV 1/5; 67/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 67/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.990 total time=   2.5s
# [CV 2/5; 69/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 2/5; 69/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   2.6s
# [CV 5/5; 70/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 5/5; 70/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.986 total time=   2.6s
# [CV 4/5; 72/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 72/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.988 total time=   2.5s
# [CV 3/5; 74/81] START max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 3/5; 74/81] END max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001;, score=0.995 total time=   4.1s
# [CV 1/5; 76/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 76/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.990 total time=   3.6s
# [CV 2/5; 78/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 2/5; 78/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.993 total time=   3.2s
# /home/grierjones/miniconda3/envs/DDGNN/lib/python3.10/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# R2: 0.9980,0.9960
# RMSE (mEh): 0.1940,0.2766

# %%
with open("y_train_3.npy", 'wb') as f:
    np.save(f,y_train)

with open("y_pred_train_3.npy", 'wb') as f:
    np.save(f,y_pred_train)  


with open("y_test_3.npy", 'wb') as f:
    np.save(f,y_test)

with open("y_pred_test_3.npy", 'wb') as f:
    np.save(f,y_pred_test)  
# y_train,y_pred_train

# %%
pd.DataFrame.from_dict(model.get_params(),orient='index').dropna().to_excel("ozone_VTZP_MS_3_70_30_params.xlsx")

# %%
try:
    os.mkdir('images')
except:
    print('./images exist')
# Out:
# ./images exist

# %%
y_train.min()*1e3,y_train.max()*1e3
# Out:
# (np.float64(-30.0537846433411), np.float64(10.9857251577737))

# %%
pal = sns.color_palette("Paired")
font=12
plt.rc('font', size=font)          # controls default text sizes
plt.rc('axes', titlesize=font)     # fontsize of the axes title
plt.rc('axes', labelsize=font)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=font)    # fontsize of the tick labels
plt.rc('ytick', labelsize=font)    # fontsize of the tick labels
plt.rc('legend', fontsize=font)    # legend fontsize
plt.rc('figure', titlesize=font)  # fontsize of the figure title
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,6))
scale=1e-1
minL,maxL = -70, 30
ax1.set_title('Train')
ax1.scatter(1e3*y_train,1e3*y_pred_train,label="R$^{2}$="+f'{r2_score(y_train,y_pred_train):.4f}\nMAE={1e3*mean_absolute_error(y_train,y_pred_train):.4f}'+" mE$_{h}$",color=pal[4],edgecolors='k')
ax1.plot(np.arange(-100,100),np.arange(-100,100),'k-')
ax1.set_xlim(minL,maxL)
ax1.set_ylim(minL,maxL)
ax1.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax1.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax1.legend()


ax2.set_title('Test')
ax2.scatter(1e3*y_test,1e3*y_pred_test,label="R$^{2}$="+f'{r2_score(y_test,y_pred_test):.4f}\nMAE={1e3*mean_absolute_error(y_test,y_pred_test):.4f}'+" mE$_{h}$",color=pal[5],edgecolors='k')
ax2.plot(np.arange(-100,100),np.arange(-100,100),'k-')
ax2.set_xlim(minL,maxL)
ax2.set_ylim(minL,maxL)
ax2.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax2.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax2.legend()

plt.tight_layout()
plt.savefig('images/ozone_VTZP_MS_3_70_30_parity.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
testcntrcvr = 0
recover_test_list = []
recover_test_E2 = []
for i,j,k,l in recover_test:
    init_test = testcntrcvr
    testcntrcvr+=l
    recover_test_list.append((i.split("_")[0],j,y_test[init_test:testcntrcvr],y_pred_test[init_test:testcntrcvr]))
    recover_test_E2.append((i.split("_")[0],j,np.sum(y_test[init_test:testcntrcvr]),np.sum(y_pred_test[init_test:testcntrcvr])))


traincntrcvr = 0
recover_train_list = []
recover_train_E2 = []
for i,j,k,l in recover_train:
    init_train = traincntrcvr
    traincntrcvr+=l
    recover_train_list.append((i.split("_")[0],j,y_train[init_train:traincntrcvr],y_pred_train[init_train:traincntrcvr]))
    recover_train_E2.append((i.split("_")[0],j,np.sum(y_train[init_train:traincntrcvr]),np.sum(y_pred_train[init_train:traincntrcvr])))

# %%
traincorrE2 = pd.DataFrame(recover_train_E2).rename(columns={0:"basis set",1:'Angle ($^{\circ}$)',2:'E$_{2}^{\text{Calculated}}$',3:'E$_{2}^{\text{Predicted}}$'})
#.astype({"basis set":str,'Angle ($^{\circ}$)':float,'E$_{2}^{\text{Calculated}}$':float,'E$_{2}^{\text{Predicted}}$':float})
testcorrE2 = pd.DataFrame(recover_test_E2).rename(columns={0:"basis set",1:'Angle ($^{\circ}$)',2:'E$_{2}^{\text{Calculated}}$',3:'E$_{2}^{\text{Predicted}}$'})
#.astype({"basis set":str,'Angle ($^{\circ}$)':float,'E$_{2}^{\text{Calculated}}$':float,'E$_{2}^{\text{Predicted}}$':float})


traincorrE2['CASPT2_E']=np.zeros(len(traincorrE2))
traincorrE2['CASSCF_E']=np.zeros(len(traincorrE2))
traincorrE2['E2']=np.zeros(len(traincorrE2))

traincorrE2.index = ["_".join((u,v)) for u,v in traincorrE2[["basis set",'Angle ($^{\circ}$)']].values]

for i in traincorrE2.index:
    
    hn, r = i.split('_')
    
    energy_df = pd.read_excel(f"{hn}/ozone_{r}/ozone_{r}_energies.xlsx",index_col=0).loc['root_3']
    
    traincorrE2.loc[i,'CASPT2_E']=energy_df.loc['CASPT2_E']
    traincorrE2.loc[i,'CASSCF_E']=energy_df.loc['CASSCF_E']
    # traincorrE2.loc[i,'E2']=energy_df.loc['E2'].values

traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'] = traincorrE2['CASSCF_E']+traincorrE2['E$_{2}^{\text{Predicted}}$']

traincorrE2.rename(columns = {'CASPT2_E':'E$_{\text{CASPT2}}^{\text{Calculated}}$','CASSCF_E':'E$_{\text{CASSCF}}^{\text{Calculated}}$'},inplace=True)


testcorrE2['CASPT2_E']=np.zeros(len(testcorrE2))
testcorrE2['CASSCF_E']=np.zeros(len(testcorrE2))
testcorrE2['E2']=np.zeros(len(testcorrE2))

testcorrE2.index = ["_".join((u,v)) for u,v in testcorrE2[["basis set",'Angle ($^{\circ}$)']].values]

for i in testcorrE2.index:
    hn, r = i.split('_')
    energy_df = pd.read_excel(f"{hn}/ozone_{r}/ozone_{r}_energies.xlsx",index_col=0).loc['root_3']
    testcorrE2.loc[i,'CASPT2_E']=energy_df.loc['CASPT2_E']
    testcorrE2.loc[i,'CASSCF_E']=energy_df.loc['CASSCF_E']
    # testcorrE2.loc[i,'E2']=energy_df.loc['E2'].values

testcorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'] = testcorrE2['CASSCF_E']+testcorrE2['E$_{2}^{\text{Predicted}}$']

testcorrE2.rename(columns = {'CASPT2_E':'E$_{\text{CASPT2}}^{\text{Calculated}}$','CASSCF_E':'E$_{\text{CASSCF}}^{\text{Calculated}}$'},inplace=True)

# %%
traincaspt2melt = traincorrE2.melt(id_vars=["basis set",'Angle ($^{\circ}$)'], value_vars=['E$_{\text{CASPT2}}^{\text{Calculated}}$','E$_{\text{CASPT2}}^{\text{Predicted}}$']).astype({'Angle ($^{\circ}$)':float,'value':float})
testcaspt2melt = testcorrE2.melt(id_vars=["basis set",'Angle ($^{\circ}$)'], value_vars=['E$_{\text{CASPT2}}^{\text{Calculated}}$','E$_{\text{CASPT2}}^{\text{Predicted}}$']).astype({'Angle ($^{\circ}$)':float,'value':float})

# %%
trueE2=pd.concat([traincorrE2,testcorrE2]).astype({'Angle ($^{\circ}$)':float,'E$_{\text{CASPT2}}^{\text{Calculated}}$':float})

# %%
mean_absolute_error(testcorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],testcorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])*1e3
# Out:
# np.float64(2.7740479412421997)

# %%
mean_absolute_error(traincorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])*1e3
# Out:
# np.float64(1.8877667621522756)

# %%
pal=sns.color_palette('Paired')

# %%
(traincorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$']-traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$']).abs().sort_values()
# Out:
# ANO-RCC-VTZP/_132.25    0.000040
# ANO-RCC-VTZP/_170.75    0.000060
# ANO-RCC-VTZP/_174.75    0.000077
# ANO-RCC-VTZP/_153.00    0.000088
# ANO-RCC-VTZP/_181.25    0.000091
#                           ...
# ANO-RCC-VTZP/_120.00    0.006169
# ANO-RCC-VTZP/_154.75    0.006620
# ANO-RCC-VTZP/_155.00    0.006825
# ANO-RCC-VTZP/_106.25    0.007052
# ANO-RCC-VTZP/_160.25    0.007674
# Length: 212, dtype: float64

# %%
allcorr = pd.concat([traincorrE2,testcorrE2])

# %%
min_max = allcorr[['E$_{2}^{\text{Predicted}}$','E$_{2}^{\text{Calculated}}$']].describe().loc[['min','max']]

# %%
mincorr = np.min(min_max) + np.min(min_max)*0.01
maxcorr = np.max(min_max) - np.max(min_max)*0.01

# %%
traincorrerr = {}

fig,((ax1,ax2),(ax3,ax4))=plt.subplots(2,2,figsize=(10,10),sharey=False)



pred_train,true_train = traincorrE2['E$_{2}^{\text{Predicted}}$'],traincorrE2['E$_{2}^{\text{Calculated}}$']
pred_test,true_test = testcorrE2['E$_{2}^{\text{Predicted}}$'],testcorrE2['E$_{2}^{\text{Calculated}}$']
testrad = testcorrE2['Angle ($^{\circ}$)']    
train_r2_corr = r2_score(true_train,pred_train)
test_r2_corr = r2_score(true_test,pred_test)
test_mae_corr = 1e3*mean_absolute_error(true_test,pred_test)
train_mae_corr = 1e3*mean_absolute_error(true_train,pred_train)
print(train_r2_corr)
traincorrerr = {"r2_train":train_r2_corr,"r2_test":test_r2_corr,"mae_train":train_mae_corr,"mae_test":test_mae_corr}
trainrad = traincorrE2['Angle ($^{\circ}$)']
ax1.scatter(true_train,pred_train,label='R$^{2}$='+f'{train_r2_corr:.4f}\nMAE={train_mae_corr:.4f}'+" mE$_{h}$",color=pal[4],edgecolors='k')

ax1.set_xlabel('Calculated CASPT2 Correlation Energy (E$_{h}$)')
ax1.set_ylabel('Predicted CASPT2 Correlation Energy (E$_{h}$)')
ax1.set_title('Train')
ax1.plot(np.arange(-1000,1000),np.arange(-1000,1000),'k')
ax1.legend(loc=4)


ax2.scatter(true_test,pred_test,label='R$^{2}$='+f'{test_r2_corr:.4f}\nMAE={test_mae_corr:.4f}'+" mE$_{h}$",color=pal[5],edgecolors='k')
# ax2.plot(true_test,true_test,'k')
ax2.plot(np.arange(-1000,1000),np.arange(-1000,1000),'k')
ax2.set_xlabel('Calculated CASPT2 Correlation Energy (E$_{h}$)')
ax2.set_ylabel('Predicted CASPT2 Correlation Energy (E$_{h}$)')

ax2.set_title('Test')    
ax2.legend(loc=4)
# vdzp
# bottom, top = -0.1035,-0.091
# vdzp
# bottom, top = -0.545,-0.505
# vtzp 
bottom, top = mincorr	,maxcorr
ax1.set_xlim(bottom, top)
ax1.set_ylim(bottom, top)
ax2.set_xlim(bottom, top)
ax2.set_ylim(bottom, top)
ax1.set_xticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)])
ax1.set_yticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)])    
# ax2.set_xlim(bottom,top)
ax2.set_xticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)])    
# ax2.set_ylim(bottom,top)
ax2.set_yticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)])    

pred_train,true_train = traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'],traincorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$']
pred_test,true_test = testcorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'],testcorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$']
testrad = testcorrE2['Angle ($^{\circ}$)']    


traincorrerr = {"r2_train":train_r2_corr,"r2_test":test_r2_corr,"mae_train":train_mae_corr,"mae_test":test_mae_corr}
trainrad = traincorrE2['Angle ($^{\circ}$)']
ax3.scatter(np.array(trainrad,dtype=float),pred_train,color=pal[4],edgecolors='k',label='Predicted CASPT2')
ax3.plot(allcorr.sort_values(by='Angle ($^{\circ}$)')['Angle ($^{\circ}$)'].astype(float),allcorr.sort_values(by='Angle ($^{\circ}$)')['E$_{\text{CASPT2}}^{\text{Calculated}}$'].astype(float),'k',label='Calculated CASPT2')
ax3.plot(allcorr.sort_values(by='Angle ($^{\circ}$)')['Angle ($^{\\circ}$)'].astype(float),allcorr.sort_values(by='Angle ($^{\circ}$)')['E$_{\text{CASSCF}}^{\text{Calculated}}$'].astype(float),'k--',label='CASSCF')
ax3.set_xlabel('Angle ($^{\circ}$)')
ax3.set_ylabel('CASPT2 Energy (E$_{h}$)')
ax3.set_title('Train')
ax3.legend()

ax4.scatter(np.array(testrad,dtype=float),pred_test,color=pal[5],edgecolors='k',label='Predicted CASPT2')
ax4.plot(allcorr.sort_values(by='Angle ($^{\circ}$)')['Angle ($^{\circ}$)'].astype(float),allcorr.sort_values(by='Angle ($^{\circ}$)')['E$_{\text{CASPT2}}^{\text{Calculated}}$'].astype(float),'k',label='Calculated CASPT2')
ax4.plot(allcorr.sort_values(by='Angle ($^{\circ}$)')['Angle ($^{\\circ}$)'].astype(float),allcorr.sort_values(by='Angle ($^{\circ}$)')['E$_{\text{CASSCF}}^{\text{Calculated}}$'].astype(float),'k--',label='CASSCF')
ax4.set_xlabel('Angle ($^{\circ}$)')
ax4.set_ylabel('CASPT2 Energy (E$_{h}$)')
ax4.set_title('Test') 
ax4.legend()

minpt2, maxpt2= pd.concat([pred_train,true_train,pred_test,true_test]).min(), pd.concat([pred_train,true_train,pred_test,true_test]).max()
print(minpt2, maxpt2)
pct=0.004
bufferbot, buffertop = minpt2*pct, maxpt2*pct



#mb
# bottom, top = -224.5, -224.1984 
#maxpt2-(buffertop) 

# vdzp: -224.40
# bottom, top = -225.2, -224.4

# vtzp
bottom, top = -225.4, -224.4
print(bottom, top)
ax3.set_ylim(bottom,top)
ax3.set_xlim(100,190)
ax3.set_yticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)]) 
ax3.set_xticks(np.linspace(100,190,4),[f"{i:.0f}" for i in np.linspace(100,190,4)]) 
ax4.set_ylim(bottom,top)
ax4.set_xlim(100,190)
ax4.set_yticks(np.linspace(bottom,top,4),[f"{i:.4f}" for i in np.linspace(bottom,top,4)]) 
ax4.set_xticks(np.linspace(100,190,4),[f"{i:.0f}" for i in np.linspace(100,190,4)]) 


fig.suptitle("O$_{3}$ ANO-RCC-VTZP")

plt.subplots_adjust(wspace=0.05)
plt.tight_layout()
plt.savefig(f'images/ozone_VTZP_MS_3_70_30CASPT2.png',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# 0.9799164968616872
# -225.22613894234132 -225.11835838
# -225.4 -224.4

# %%
trainpairdf = pd.DataFrame(recover_train_list)
testpairdf = pd.DataFrame(recover_test_list)
pairerr={}

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5),sharey=True)

truetrainpair, predtrainpair = np.hstack(trainpairdf[2]),np.hstack(trainpairdf[3])
train_r2_pair = r2_score(truetrainpair, predtrainpair)
train_mae_pair = 1e3*mean_absolute_error(truetrainpair, predtrainpair)
ax1.scatter(truetrainpair, predtrainpair,label='R$^{2}$='+f'{train_r2_pair:.4f}\nMAE={train_mae_pair:.4f}'+" mE$_{h}$",color=pal[4],edgecolors='k')
ax1.plot(np.arange(-1000,1000),np.arange(-1000,1000),'k')
ax1.set_xlabel('Calculated E$_2$ Energy (E$_{h}$)')
ax1.set_ylabel('Predicted E$_2$ Energy (E$_{h}$)')
ax1.set_title('Train')    
ax1.legend()  

truetestpair, predtestpair = np.hstack(testpairdf[2]),np.hstack(testpairdf[3])
test_r2_pair = r2_score(truetestpair, predtestpair)
test_mae_pair = 1e3*mean_absolute_error(truetestpair, predtestpair)
ax2.scatter(truetestpair, predtestpair,label='R$^{2}$='+f'{test_r2_pair:.4f}\nMAE={test_mae_pair:.4f}'+" mE$_{h}$",color=pal[5],edgecolors='k')
ax2.plot(np.arange(-1000,1000),np.arange(-1000,1000),'k')
ax2.set_xlabel('Calculated E$_2$ Energy (E$_{h}$)')
ax2.set_ylabel('Predicted E$_2$ Energy (E$_{h}$)')
ax2.set_title('Test')    
ax2.legend()    

mincorr, maxcorr= np.hstack([truetrainpair,truetestpair]).min(), np.hstack([truetrainpair,truetestpair]).max()
pct=0.50
bufferbot, buffertop = mincorr*pct, maxcorr*pct

# if 'H' in n:
bottom, top = mincorr-buffertop, maxcorr+buffertop

# else:
#     bottom, top = mincorr+-0.1, maxcorr+0.05

ax1.set_xlim(bottom,top)
ax1.set_xticks(np.linspace(bottom,top,4),[f"{i:.2f}" for i in np.linspace(bottom,top,4)])
ax1.set_ylim(bottom,top)
ax1.set_yticks(np.linspace(bottom,top,4),[f"{i:.2f}" for i in np.linspace(bottom,top,4)])    
ax2.set_xlim(bottom,top)
ax2.set_xticks(np.linspace(bottom,top,4),[f"{i:.2f}" for i in np.linspace(bottom,top,4)])    
ax2.set_ylim(bottom,top)
ax2.set_yticks(np.linspace(bottom,top,4),[f"{i:.2f}" for i in np.linspace(bottom,top,4)])    

fig.suptitle("O$_{3}$ ANO-RCC-MB")
plt.tight_layout()
plt.savefig(f'images/ozone_VTZP_MS_3_70_30E2.png',dpi=300,bbox_inches='tight')    
plt.show()
pairerr = {"r2_train":train_r2_pair,"r2_test":test_r2_pair,"mae_train":train_mae_pair,"mae_test":test_mae_pair}

# %%
trainpairmae = np.array([mean_absolute_error(u,v) for u,v in np.vstack([trainpairdf[2],trainpairdf[3]]).T])
testpairmae = np.array([mean_absolute_error(u,v) for u,v in np.vstack([testpairdf[2],testpairdf[3]]).T])

# %%
np.argsort(trainpairmae)[-5:],np.round(1e3*trainpairmae[np.argsort(trainpairmae)[-10:]],4)
# Out:
# (array([121,  12, 173, 203, 167]),
#  array([0.1953, 0.1969, 0.2054, 0.2092, 0.2113, 0.2131, 0.2233, 0.2233,
#         0.2423, 0.2677]))

# %%
cleanedtrain = traincorrE2.drop(index=traincorrE2.iloc[np.argsort(trainpairmae)[-10:]].index)

# %%
traincorrE2.iloc[np.argsort(trainpairmae)[-10:]]
# Out:
#                           basis set Angle ($^{\circ}$)  \
# ANO-RCC-VTZP/_156.00  ANO-RCC-VTZP/             156.00
# ANO-RCC-VTZP/_157.25  ANO-RCC-VTZP/             157.25
# ANO-RCC-VTZP/_121.25  ANO-RCC-VTZP/             121.25
# ANO-RCC-VTZP/_106.25  ANO-RCC-VTZP/             106.25
# ANO-RCC-VTZP/_157.00  ANO-RCC-VTZP/             157.00
# ANO-RCC-VTZP/_120.50  ANO-RCC-VTZP/             120.50
# ANO-RCC-VTZP/_156.25  ANO-RCC-VTZP/             156.25
# ANO-RCC-VTZP/_181.75  ANO-RCC-VTZP/             181.75
# ANO-RCC-VTZP/_106.00  ANO-RCC-VTZP/             106.00
# ANO-RCC-VTZP/_120.75  ANO-RCC-VTZP/             120.75
#
#                       E$_{2}^{\text{Calculated}}$  E$_{2}^{\text{Predicted}}$  \
# ANO-RCC-VTZP/_156.00                    -0.576179                   -0.581112
# ANO-RCC-VTZP/_157.25                    -0.598048                   -0.599582
# ANO-RCC-VTZP/_121.25                    -0.569330                   -0.565094
# ANO-RCC-VTZP/_106.25                    -0.569767                   -0.576821
# ANO-RCC-VTZP/_157.00                    -0.597862                   -0.600848
# ANO-RCC-VTZP/_120.50                    -0.574903                   -0.571022
# ANO-RCC-VTZP/_156.25                    -0.576288                   -0.578320
# ANO-RCC-VTZP/_181.75                    -0.619269                   -0.614983
# ANO-RCC-VTZP/_106.00                    -0.569671                   -0.574707
# ANO-RCC-VTZP/_120.75                    -0.574991                   -0.575688
#
#                       E$_{\text{CASPT2}}^{\text{Calculated}}$  \
# ANO-RCC-VTZP/_156.00                              -225.120007
# ANO-RCC-VTZP/_157.25                              -225.148868
# ANO-RCC-VTZP/_121.25                              -225.218512
# ANO-RCC-VTZP/_106.25                              -225.206903
# ANO-RCC-VTZP/_157.00                              -225.148791
# ANO-RCC-VTZP/_120.50                              -225.224180
# ANO-RCC-VTZP/_156.25                              -225.119182
# ANO-RCC-VTZP/_181.75                              -225.157433
# ANO-RCC-VTZP/_106.00                              -225.206377
# ANO-RCC-VTZP/_120.75                              -225.224281
#
#                       E$_{\text{CASSCF}}^{\text{Calculated}}$   E2  \
# ANO-RCC-VTZP/_156.00                              -224.543829  0.0
# ANO-RCC-VTZP/_157.25                              -224.550819  0.0
# ANO-RCC-VTZP/_121.25                              -224.649182  0.0
# ANO-RCC-VTZP/_106.25                              -224.637134  0.0
# ANO-RCC-VTZP/_157.00                              -224.550927  0.0
# ANO-RCC-VTZP/_120.50                              -224.649276  0.0
# ANO-RCC-VTZP/_156.25                              -224.542893  0.0
# ANO-RCC-VTZP/_181.75                              -224.538163  0.0
# ANO-RCC-VTZP/_106.00                              -224.636706  0.0
# ANO-RCC-VTZP/_120.75                              -224.649293  0.0
#
#                       E$_{\text{CASPT2}}^{\text{Predicted}}$
# ANO-RCC-VTZP/_156.00                             -225.124941
# ANO-RCC-VTZP/_157.25                             -225.150401
# ANO-RCC-VTZP/_121.25                             -225.214276
# ANO-RCC-VTZP/_106.25                             -225.213955
# ANO-RCC-VTZP/_157.00                             -225.151776
# ANO-RCC-VTZP/_120.50                             -225.220299
# ANO-RCC-VTZP/_156.25                             -225.121214
# ANO-RCC-VTZP/_181.75                             -225.153146
# ANO-RCC-VTZP/_106.00                             -225.211413
# ANO-RCC-VTZP/_120.75                             -225.224981

# %%
traincorrE2.drop(columns='E2').to_excel('train_ozone_VTZP_MS_3_70_30_energies.xlsx')
testcorrE2.drop(columns='E2').to_excel('test_ozone_VTZP_MS_3_70_30_energies.xlsx')

# %%
np.round(1e3*mean_absolute_error(cleanedtrain['E$_{2}^{\text{Calculated}}$'],cleanedtrain['E$_{2}^{\text{Predicted}}$']),4)
# Out:
# np.float64(1.7997)

# %%
np.round(r2_score(cleanedtrain['E$_{2}^{\text{Calculated}}$'],cleanedtrain['E$_{2}^{\text{Predicted}}$']),4)
# Out:
# np.float64(0.9818)

# %%
plt.bar(*np.vstack([trainpairdf[1].astype(float),[mean_absolute_error(u,v) for u,v in np.vstack([trainpairdf[2],trainpairdf[3]]).T]]))
# Out:
# <BarContainer object of 212 artists>

# %%
plt.bar(*np.vstack([testpairdf[1].astype(float),[mean_absolute_error(u,v) for u,v in np.vstack([testpairdf[2],testpairdf[3]]).T]]))
# Out:
# <BarContainer object of 92 artists>

# %%
plt.bar(*np.vstack([trainpairdf[1].astype(float),[mean_absolute_error(u,v) for u,v in np.vstack([trainpairdf[2],trainpairdf[3]]).T]]))
# Out:
# <BarContainer object of 212 artists>

# %%
stackeddata ={'Pair-Energies':{'Train':mean_absolute_error(truetrainpair, predtrainpair)*1e3,'Test':mean_absolute_error(truetestpair, predtestpair)*1e3},
"Correlation Energies":{'Train':mean_absolute_error(true_train,pred_train)*1e3,'Test':mean_absolute_error(pred_test,true_test)*1e3}}
pd.DataFrame(stackeddata).to_excel("MAE_stacked_VTZP_MS_3_70_30.xlsx")

# %%
# meltcorrerr = pd.DataFrame.from_dict(traincorrerr).loc[['mae_train','mae_test']].T.rename(columns={'mae_train':'Train','mae_test':'Test'}).reset_index().melt(id_vars=['index'], value_vars=['Train','Test'])
# meltpairerr = pd.DataFrame.from_dict(pairerr).loc[['mae_train','mae_test']].T.rename(columns={'mae_train':'Train','mae_test':'Test'}).reset_index().melt(id_vars=['index'], value_vars=['Train','Test'])
# fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,5),sharey=True)
# sns.barplot(data=meltpairerr,x='index',y='value',hue='variable',palette=pal[4:6],ax=ax1)
# ax1.set_ylabel('Mean Absolute Error (mE$_{h}$)')
# ax1.set_xlabel('Structures')
# ax1.set_title('Pair-Energies')
# ax1.set_ylim(0,2.5)
# sns.barplot(data=meltcorrerr,x='index',y='value',hue='variable',palette=pal[4:6],ax=ax2)
# # ax2.set_ylabel('Mean Absolute Error (mE$_{h}$)')
# ax2.set_ylabel('')
# ax2.set_xlabel('Structures')
# ax2.set_title('Correlation Energies')

# plt.tight_layout()
# plt.savefig('images/MAE_bar.png',dpi=300,bbox_inches='tight')
# plt.show()

# %%
import shap
explainer = shap.Explainer(model.predict, X_test)
shap_values = explainer(X_test)

dffeat=pd.DataFrame(shap_values.abs.values.mean(axis=0),index=train_df.drop(columns=['Pair_Energies']).columns,columns=['shap']).rename(index={'1':'$\mathbf{b}$'}).reset_index().rename(columns={'index':'feat'}).sort_index().sort_values(by=['shap','feat'],ascending=False)
# dffeat['rename']=len(dffeat)*[1]
with open('ozone_VTZP_MS_3_70_30_feature_names.txt','w') as f:
    for i in dffeat['feat'].values:
        f.write(i+'\n')

with open('feature_names.txt','w') as f:
    for i in dffeat['feat'].values:
        f.write(i+'\n')
dffeat.to_excel('ozone_VTZP_MS_3_70_30_SHAP.xlsx')
# dffeat = pd.read_excel('ozone_VTZP_MS_3_70_30_SHAP.xlsx')
# Out:
# PermutationExplainer explainer: 14353it [02:36, 86.73it/s]

# %%
color_map=sns.color_palette('rocket',6)
fontsize = 12
fig, ax = plt.subplots(1,3,figsize=(15,12))
for idx, i in enumerate([[ 0,  35], [35,  70], [70, 105]]):
    print(idx,i)
    feat_1 = dffeat.iloc[i[0]:i[1]]
    ax[idx]=feat_1.sort_values(by=['shap','feat']).plot.barh(x='feat',y='shap',legend=False,color=color_map[3],fontsize=fontsize,ax=ax[idx])
    ax[idx].bar_label(ax[idx].containers[0], fmt='%.4e',fontsize=fontsize,padding=1)
    top_max = 1.5e-3
    ax[idx].set_xlim(0,top_max)
    ax[idx].set_xticks(np.linspace(0,top_max,4),[f"{i:.2e}" for i in np.linspace(0,top_max,4)])
    ax[idx].set_ylabel('Features',fontsize=fontsize)
    ax[idx].set_xlabel('mean(|SHAP value|)',fontsize=fontsize)

fig.subplots_adjust(wspace=0, hspace=0)

plt.tight_layout()
plt.savefig('images/ozone_VTZP_MS_3_70_30_shap_bar.png',dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0 [0, 35]
# 1 [35, 70]
# 2 [70, 105]

# %%
fig, ax = plt.subplots(1,1,figsize=(12,12))
fontsize = 16
pd.concat([dffeat.sort_values(by='shap').iloc[0:10],dffeat.sort_values(by='shap').iloc[-10:]]).plot.barh(x='feat',y='shap',legend=False,color=color_map[3],fontsize=fontsize,ax=ax)
ax.bar_label(ax.containers[0], fmt='%.4e',fontsize=fontsize,padding=1)
top_max = 1e-3
ax.set_xlim(0,top_max)
ax.set_xticks(np.linspace(0,top_max,4),[f"{i:.2e}" for i in np.linspace(0,top_max,4)])
ax.set_ylabel('Features',fontsize=fontsize)
ax.set_xlabel('mean(|SHAP value|)',fontsize=fontsize)

fig.subplots_adjust(wspace=0, hspace=0)

plt.tight_layout()
plt.savefig('images/minmax_ozone_VTZP_MS_3_70_30_shap_bar.png',dpi=300, bbox_inches='tight')
plt.show()

# %%
# # plt.figure(figsize=(8,13))
# color_map=sns.color_palette('rocket',6)
# fontsize = 5

# feat_2 = dffeat.sort_values(by=['shap','feat']).iloc[:63]
# feat_1 = dffeat.sort_values(by=['shap','feat']).iloc[63:]


# ax1=feat_1.sort_values(by=['shap','feat']).plot.barh(x='feat',y='shap',legend=False,color=color_map[3],fontsize=fontsize,ax=ax1)
# ax1.bar_label(ax1.containers[0], fmt='%.4e',fontsize=fontsize,padding=1)
# ax1.set_xlim(0,5e-4)
# ax1.set_xticks(np.linspace(0,5e-4,4),[f"{i:.2e}" for i in np.linspace(0,5e-4,4)])
# ax1.set_ylabel('Features',fontsize=fontsize)
# ax1.set_xlabel('mean(|SHAP value|)',fontsize=fontsize)

# ax2=feat_2.sort_values(by=['shap','feat']).plot.barh(x='feat',y='shap',legend=False,color=color_map[3],fontsize=fontsize,ax=ax2)
# ax2.bar_label(ax2.containers[0], fmt='%.4e',fontsize=fontsize,padding=1)
# ax2.set_xlim(0,5e-4)
# ax2.set_xticks(np.linspace(0,5e-4,4),[f"{i:.2e}" for i in np.linspace(0,5e-4,4)])
# ax2.set_ylabel('')
# ax2.set_xlabel('mean(|SHAP value|)',fontsize=fontsize)

# plt.tight_layout()
# # os.mkdir('images')
# plt.savefig('images/Hn_shap_bar.png',dpi=300, bbox_inches='tight')
# plt.show()

# %%
dffeat.sort_values(by='shap').iloc[-10:]['feat'].to_list()
# Out:
# ['$(\\langle pq \\vert pq \\rangle)_{0}$',
#  '$(\\langle pq \\vert pq \\rangle)_{3}$',
#  'h$_{s}$',
#  '$(F_{p})_{3}$',
#  '$\\langle qq \\vert qq \\rangle$',
#  '$\\langle ss \\vert ss \\rangle$',
#  '$(\\eta_{p})_{3}$',
#  '$\\eta_{s}$',
#  '$\\eta_{q}$',
#  '$F_{q}^{\\text{SCF}}$']

# %%
for f in dffeat.sort_values(by='shap').iloc[-10:]['feat']:
    try:
        sns.kdeplot(pd.concat([train_df,test_df])[f])
    except:
        print(f)
    plt.title(f)
    plt.show()

# %%
dffeat.sort_values(by='shap').iloc[-10:]['feat'].tolist()
# Out:
# ['$(\\langle pq \\vert pq \\rangle)_{0}$',
#  '$(\\langle pq \\vert pq \\rangle)_{3}$',
#  'h$_{s}$',
#  '$(F_{p})_{3}$',
#  '$\\langle qq \\vert qq \\rangle$',
#  '$\\langle ss \\vert ss \\rangle$',
#  '$(\\eta_{p})_{3}$',
#  '$\\eta_{s}$',
#  '$\\eta_{q}$',
#  '$F_{q}^{\\text{SCF}}$']

# %%
for f in dffeat.sort_values(by='shap').iloc[0:10]['feat']:
    try:
        # print(f,((pd.concat([train_df,test_df])[f]).value_counts()/len(pd.concat([train_df,test_df])[f])).round(2))
        sns.histplot(pd.concat([train_df,test_df])[f])
    except:
        if f=='$\mathbf{b}$':
            sns.kdeplot(pd.concat([train_df,test_df])['1'])
        else:
            sns.kdeplot(pd.concat([train_df,test_df])[fr"{f}"],color='r')
    plt.title(f)
    plt.show()
    # print()

# %%
r2_score(traincorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])

# %%
r2_score(testcorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],testcorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])

# %%
mean_absolute_error(traincorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],traincorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])*1e3

# %%
mean_absolute_error(testcorrE2['E$_{\text{CASPT2}}^{\text{Calculated}}$'],testcorrE2['E$_{\text{CASPT2}}^{\text{Predicted}}$'])*1e3
