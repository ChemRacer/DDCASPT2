# %%
# For data generation
import sys
# !{sys.executable} -m pip install xgboost --upgrade
import shutil
import os
import numpy as np
from glob import glob
import re
import pandas as pd
import pickle
#random
from time import perf_counter

# sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV


#Plotting
import seaborn as sns
sns.set_style()
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 200

import warnings
# warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 


from tqdm.auto import tqdm
# from tqdm.notebook import tqdm_notebook as tqdm

# %%
with open('test_ind.pickle', 'rb') as handle:
    test_ind = pickle.load(handle)

with open('train_ind.pickle', 'rb') as handle:
    train_ind = pickle.load(handle)
    
print(len(train_ind),len(test_ind))
# Out:
# 76 76

# %%
# feat_name=['From_Same_Orbital', 'pair_energy', 'coulomb', 'screen1_1', 'screen1_2',
#        'screen1_3', 'screen1_4', 'screen2_1', 'screen2_2', 'screen2_3',
#        'screen2_4', 'eijab_1', 'eijab_2', 'eijab_3', 'eijab_4', 'screenvirt_1',
#        'screenvirt_2', 'screenvirt_3', 'screenvirt_4', 'Fr1', 'Fr2', 'Fr3',
#        'Fr4', 'Fs1', 'Fs2', 'Fs3', 'Fs4', 'occr1', 'occr2', 'occr3', 'occr4',
#        'occs1', 'occs2', 'occs3', 'occs4', 'SCFFr1', 'SCFFr2', 'SCFFr3',
#        'SCFFr4', 'SCFFs1', 'SCFFs2', 'SCFFs3', 'SCFFs4', 'SCFOCCr1',
#        'SCFOCCr2', 'SCFOCCr3', 'SCFOCCr4', 'SCFOCCs1', 'SCFOCCs2', 'SCFOCCs3',
#        'SCFOCCs4', 'hrr1', 'hrr2', 'hrr3', 'hrr4', 'hss1', 'hss2', 'hss3',
#        'hss4', 'hpp', 'hqq', 'Fp', 'Fq', 'occp', 'occq', 'SCFFp', 'SCFFq',
#        'SCFOCCp', 'SCFOCCq']

# feat_name=['occs3',
#  'SCFOCCs2',
#  'SCFOCCs1',
#  'screen2_1',
#  'SCFOCCp',
#  'hss4',
#  'hrr1',
#  'Fs2',
#  'occq',
#  'screenvirt_4',
#  'SCFFs2',
#  'hrr3',
#  'SCFFr1',
#  'screenvirt_2',
#  'screenvirt_3',
#  'SCFFs4',
#  'hss2',
#  'screen1_2',
#  'hrr4',
#  'screen1_3',
#  'Fp',
#  'Fr1',
#  'screenvirt_1',
#  'occs4',
#  'screen2_4',
#  'SCFFr2',
#  'eijab_2',
#  'screen2_3',
#  'SCFFs1',
#  'eijab_4',
#  'Fq',
#  'hss1',
#  'SCFFr4',
#  'occs2',
#  'occp',
#  'screen1_4',
#  'eijab_1',
#  'hpp',
#  'pair_energy',
#  'hrr2',
#  'hqq',
#  'SCFFr3',
#  'occs1',
#  'Fr2',
#  'eijab_3',
#  'SCFOCCq',
#  'SCFOCCs4',
#  'Fs3',
#  'Fs1',
#  'From_Same_Orbital',
#  'hss3',
#  'Fs4',
#  'SCFOCCs3',
#  'Fr4',
#  'screen2_2',
#  'screen1_1',
#  'Fr3',
#  'SCFFs3']

feat_name=['SCFFs3',
 'hrr3',
 'screen1_1',
 'SCFOCCs2',
 'hpp',
 'SCFOCCs3',
 'hss4',
 'screen2_2',
 'SCFOCCq',
 'hss1',
 'screenvirt_3',
 'SCFFs4',
 'SCFFr4',
 'SCFOCCs1',
 'SCFFr3',
 'hss2',
 'screen2_4',
 'screenvirt_2',
 'SCFFs2',
 'hss3',
 'hqq',
 'hrr4',
 'hrr1',
 'screen1_3',
 'SCFOCCs4',
 'SCFFr1',
 'SCFFs1',
 'hrr2',
 'SCFFr2',
 'screen1_4',
 'screen2_1',
 'screenvirt_1',
 'screen1_2',
 'SCFOCCp',
 'screen2_3',
 'screenvirt_4']

# %%
# Xcheck=pd.DataFrame(np.vstack([np.vstack(train_X),np.vstack(test_X)]),columns=feat_name)

# %%
train_X=[]
train_y = []

test_X=[]
test_y = []

nam='O3/fixed_feats.pickle'
trydf=pd.read_pickle(nam).astype(float)[feat_name]  
# trydf.set_index(trydf.index.set_levels([int(i.split('/')[1].split('_')[1]) for i in trydf.index.levels[0]],level=0),inplace=True)

for i in train_ind:
    train_X.append(trydf.loc[f"{i:.2f}"].values)
for j in test_ind: 
    test_X.append(trydf.loc[f"{j:.2f}"].values)

# %%
trydf
# Out:
#                 SCFFs3   hrr3  screen1_1  SCFOCCs2    hpp  SCFOCCs3   hss4  \
# 161.00 A1_A1  0.293461 -13.13   0.474513  0.000000 -11.12  0.000000 -12.17
#        A1_A2  0.000000 -12.57   0.474513  1.451590 -11.12  1.994053 -11.12
#        A1_A3  0.000000 -13.13   0.474513  1.994053 -11.12  0.554356 -12.17
#        A2_A1  0.293461 -13.13   0.582896  0.000000 -12.09  0.000000 -12.57
#        A2_A2  0.293461 -13.13   0.518220  0.000000 -12.09  0.000000 -12.17
# ...                ...    ...        ...       ...    ...       ...    ...
# 158.00 I9_I5  0.000000 -12.18   0.462871  1.716603 -11.66  1.980232 -13.12
#        I9_I6  0.104275 -13.12   0.511381  0.000000 -11.66  0.000000 -12.60
#        I9_I7  0.104275 -13.12   0.511381  0.000000 -11.66  0.000000 -12.60
#        I9_I8  0.104275 -13.12   0.511381  0.000000 -11.66  0.000000 -12.60
#        I9_I9  0.000000 -12.08   0.462871  0.303165 -11.66  1.716603 -11.14
#
#               screen2_2   SCFOCCq   hss1  ...    SCFFs1   hrr2    SCFFr2  \
# 161.00 A1_A1   0.453841  1.994053 -12.57  ...  0.293461 -13.13  0.360002
#        A1_A2   0.000000  1.451590 -12.17  ...  0.000000 -13.13  0.360002
#        A1_A3   0.000000  0.554356 -12.09  ...  0.000000 -13.13  0.360002
#        A2_A1   0.474513  1.994053 -12.57  ...  0.293461 -13.13  0.360002
#        A2_A2   0.582896  1.451590 -12.57  ...  0.293461 -13.13  0.360002
# ...                 ...       ...    ...  ...       ...    ...       ...
# 158.00 I9_I5   0.476897  2.000000 -12.18  ...  0.000000 -12.08  0.000000
#        I9_I6   0.463831  2.000000 -13.12  ...  0.585746 -13.12  0.585746
#        I9_I7   0.495604  2.000000 -13.12  ...  0.585746 -13.12  0.585746
#        I9_I8   0.499003  2.000000 -13.12  ...  0.585746 -13.12  0.585746
#        I9_I9   0.462871  2.000000 -12.18  ...  0.000000 -12.18  0.000000
#
#               screen1_4  screen2_1  screenvirt_1  screen1_2   SCFOCCp  \
# 161.00 A1_A1   0.453841   0.474513      0.601941   0.453841  1.994053
#        A1_A2   0.453841   0.000000      0.535016   0.453841  1.994053
#        A1_A3   0.474513   0.000000      0.518220   0.453841  1.994053
#        A2_A1   0.582896   0.474513      0.610555   0.582896  1.451590
#        A2_A2   0.582896   0.518220      0.601941   0.582896  1.451590
# ...                 ...        ...           ...        ...       ...
# 158.00 I9_I5   0.511381   0.475680      0.000000   0.468016  2.000000
#        I9_I6   0.495018   0.475632      0.730141   0.511381  2.000000
#        I9_I7   0.495018   0.533451      0.730141   0.511381  2.000000
#        I9_I8   0.511381   0.525485      0.730141   0.511381  2.000000
#        I9_I9   0.462871   0.462871      0.000000   0.462871  2.000000
#
#               screen2_3  screenvirt_4
# 161.00 A1_A1   0.474513      0.590128
#        A1_A2   0.000000      0.453841
#        A1_A3   0.000000      0.535016
#        A2_A1   0.474513      0.610555
#        A2_A2   0.518220      0.590128
# ...                 ...           ...
# 158.00 I9_I5   0.475718      0.730141
#        I9_I6   0.463831      0.608912
#        I9_I7   0.495604      0.608912
#        I9_I8   0.499003      0.612284
#        I9_I9   0.468016      0.000000
#
# [14288 rows x 36 columns]

# %%
# This recover is wrong... did not account for the # of pair-energies     
recover_train=[]    
recover_test=[]    
tst_idx=0
tr_idx=0
for nidx,nam in enumerate(glob('*/fixed_targets.pickle')):
    print(nam)
    tryy=pd.read_pickle(nam).astype(float)
    Hnam=nam.split('/')[0].split('_')[0]
    for tridx,i in enumerate(train_ind):
        pairdf=tryy[f"{i:.2f}"].values
        train_y.append(pairdf)
        for k in range(len(pairdf)):
            recover_train.append((float(i),tridx,tr_idx))
            tr_idx+=1
        
    for teidx,j in enumerate(test_ind): 
        pairdf=tryy[f"{j:.2f}"].values
        test_y.append(pairdf)        
        
        for k in range(len(pairdf)):
            recover_test.append((float(j),teidx,tst_idx))
            tst_idx+=1
# Out:
# O3/fixed_targets.pickle

# %%
X_train, X_test=np.vstack(train_X).astype(float),np.vstack(test_X).astype(float)
for u,v in np.argwhere(np.isnan(X_train)):
    X_train[u,v]=0
    
for u,v in np.argwhere(np.isnan(X_test)):
    X_test[u,v]=0

# %%
y_train,y_test=np.hstack(train_y).astype(float),np.hstack(test_y).astype(float)

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (7144, 36) (7144, 36)

# %%
from xgboost import XGBRegressor
# model=XGBRegressor(reg_lambda=0.3,max_depth=100,min_child_weight=5)
# model=XGBRegressor(max_depth=100,min_child_weight=1,n_estimators=100, reg_alpha=0.001, reg_lambda=0.001)
# model.fit(X_train,y_train)
# y_pred_train=model.predict(X_train)
# y_pred_test=model.predict(X_test)
# print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
# print(f"RMSE (mEh): {mean_squared_error(y_train,y_pred_train,squared=False)*1e3:.4f},{mean_squared_error(y_test,y_pred_test,squared=False)*1e3:.4f}")

params = {'max_depth': [1, 10, 100],
          'n_estimators': [100, 500, 1000],
          'reg_lambda': [1e-6, 1e-3,1e-1],
          'reg_alpha': [1e-6, 1e-3,1e-1]}

model = XGBRegressor()
grid = GridSearchCV(estimator=model, 
                   param_grid=params,
                   scoring='r2', 
                   verbose=1000,n_jobs=12).fit(X_train,y_train)


gmodel=grid.best_estimator_
gmodel.device = 'cuda:0'
y_pred_train=gmodel.predict(X_train)
y_pred_test=gmodel.predict(X_test)
print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
print(f"RMSE (mEh): {mean_squared_error(y_train,y_pred_train,squared=False)*1e3:.4f},{mean_squared_error(y_test,y_pred_test,squared=False)*1e3:.4f}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# R2: 0.6247,0.3946
# RMSE (mEh): 1.8754,2.4100
# /home/grierjones/miniconda3/envs/DDGNN/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /home/grierjones/miniconda3/envs/DDGNN/lib/python3.10/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
font=12
plt.rc('font', size=font)          # controls default text sizes
plt.rc('axes', titlesize=font)     # fontsize of the axes title
plt.rc('axes', labelsize=font)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=font)    # fontsize of the tick labels
plt.rc('ytick', labelsize=font)    # fontsize of the tick labels
plt.rc('legend', fontsize=font)    # legend fontsize
plt.rc('figure', titlesize=font)  # fontsize of the figure title
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,6))
scale=1e-1
ax1.set_title('Train')
ax1.scatter(1e3*y_train,1e3*y_pred_train,label="R$^{2}$="+f'{r2_score(y_train,y_pred_train):.2f}\nMAE={1e3*mean_absolute_error(y_train,y_pred_train):.4f}'+" mE$_{h}$")
ax1.plot(1e3*y_train,1e3*y_train,'k-')
ax1.set_xlim(1e3*min(y_train)-scale,1e3*max(y_train)+scale)
ax1.set_ylim(1e3*min(y_train)-scale,1e3*max(y_train)+scale)
ax1.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax1.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax1.legend()


ax2.set_title('Test')
ax2.scatter(1e3*y_test,1e3*y_pred_test,label="R$^{2}$="+f'{r2_score(y_test,y_pred_test):.2f}\nMAE={1e3*mean_absolute_error(y_test,y_pred_test):.4f}'+" mE$_{h}$",color='orange')
ax2.plot(1e3*y_test,1e3*y_test,'k-')
ax2.set_xlim(1e3*min(y_test)-scale,1e3*max(y_test)+scale)
ax2.set_ylim(1e3*min(y_test)-scale,1e3*max(y_test)+scale)
ax2.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax2.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax2.legend()
if os.path.exists('images')==False:
    os.mkdir('images')
plt.tight_layout()
plt.savefig('images/O3_parity.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
testdct=[np.vstack((y_test[np.array(recover_test)[np.array(recover_test)[:,1].astype(int)==i][:,2].astype(int)],y_pred_test[np.array(recover_test)[np.array(recover_test)[:,1].astype(int)==i][:,2].astype(int)])) for i in np.unique(np.array(recover_test)[:,1].astype(int))]

test_errors=mean_absolute_error(np.hstack(testdct)[0],np.hstack(testdct)[1])*1e3

# %%
traindct=[np.vstack((y_train[np.array(recover_train)[np.array(recover_train)[:,1].astype(int)==i][:,2].astype(int)],y_pred_train[np.array(recover_train)[np.array(recover_train)[:,1].astype(int)==i][:,2].astype(int)])) for i in np.unique(np.array(recover_train)[:,1].astype(int))]

train_errors=mean_absolute_error(np.hstack(traindct)[0],np.hstack(traindct)[1])*1e3

# %%
CASSCF=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/CASSCF.csv')],axis=1)
CASPT2=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/CASPT2.csv')],axis=1)
E2=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/E2.csv')],axis=1)    

# CASSCF.index=[f'{int(i)}' for i in CASSCF.index]
# CASPT2.index=[f'{int(i)}' for i in CASPT2.index]
# E2.index=[f'{int(i)}' for i in E2.index]

# %%
pairedcp=sns.color_palette('Paired')

# %%
test_E2={np.unique(np.array(recover_test)[:,0])[idx]:{'true':sum(u),'pred':sum(v)} for idx,(u,v) in enumerate(testdct)}
train_E2={np.unique(np.array(recover_train)[:,0])[idx]:{'true':sum(u),'pred':sum(v)} for idx,(u,v) in enumerate(traindct)}

# %%
mean_absolute_error(CASSCF.values,CASPT2.values)
# Out:
# np.float64(0.09831214092105219)

# %%
CASPT2.loc[106.0]
# Out:
# O3/CASPT2.csv   -224.453709
# Name: 106.0, dtype: float64

# %%
[(k,v['pred']) for k,v in train_E2.items()]
# Out:
# [(np.float64(106.0), np.float64(-0.08219640713650733)),
#  (np.float64(107.0), np.float64(-0.09214351244008867)),
#  (np.float64(108.0), np.float64(-0.09312739659071667)),
#  (np.float64(109.0), np.float64(-0.0953709447348956)),
#  (np.float64(110.0), np.float64(-0.09581434103893116)),
#  (np.float64(111.0), np.float64(-0.09424471994134365)),
#  (np.float64(112.0), np.float64(-0.09374125940667)),
#  (np.float64(113.0), np.float64(-0.09237709944864037)),
#  (np.float64(114.0), np.float64(-0.09266270310217806)),
#  (np.float64(115.0), np.float64(-0.09367442577240581)),
#  (np.float64(116.0), np.float64(-0.09286073508155823)),
#  (np.float64(117.0), np.float64(-0.09278028181324771)),
#  (np.float64(118.0), np.float64(-0.09162251588168147)),
#  (np.float64(119.0), np.float64(-0.09330260827300663)),
#  (np.float64(120.0), np.float64(-0.09301632784081448)),
#  (np.float64(121.0), np.float64(-0.09708694087203185)),
#  (np.float64(122.0), np.float64(-0.10272949470891035)),
#  (np.float64(123.0), np.float64(-0.10316255225552595)),
#  (np.float64(124.0), np.float64(-0.1009060001179023)),
#  (np.float64(125.0), np.float64(-0.09887607336168003)),
#  (np.float64(126.0), np.float64(-0.10156950653072272)),
#  (np.float64(127.0), np.float64(-0.10359200932180102)),
#  (np.float64(128.0), np.float64(-0.09951219590038818)),
#  (np.float64(129.0), np.float64(-0.102181926378762)),
#  (np.float64(130.0), np.float64(-0.10457437645709433)),
#  (np.float64(131.0), np.float64(-0.10496898192104709)),
#  (np.float64(132.0), np.float64(-0.10594365865290456)),
#  (np.float64(133.0), np.float64(-0.10536915250304446)),
#  (np.float64(134.0), np.float64(-0.09900282108901592)),
#  (np.float64(167.0), np.float64(-224.3922005054326)),
#  (np.float64(168.0), np.float64(-224.3903622090511)),
#  (np.float64(169.0), np.float64(-224.38073557130258)),
#  (np.float64(170.0), np.float64(-224.37984167234518)),
#  (np.float64(171.0), np.float64(-224.3680498667568)),
#  (np.float64(172.0), np.float64(-224.37786001699277)),
#  (np.float64(173.0), np.float64(-224.38487468395394)),
#  (np.float64(174.0), np.float64(-224.37631707956143)),
#  (np.float64(175.0), np.float64(-224.3821778740637)),
#  (np.float64(176.0), np.float64(-224.3694310473)),
#  (np.float64(177.0), np.float64(-224.36918517891533)),
#  (np.float64(178.0), np.float64(-224.36393241277602)),
#  (np.float64(179.0), np.float64(-224.36177058233235)),
#  (np.float64(180.0), np.float64(-224.36638874162216)),
#  (np.float64(181.0), np.float64(-224.36656194421604))]

# %%
melted_train=np.array([(k,(CASSCF.loc[k].values+v['pred'])[0]) for k,v in train_E2.items()]).astype(float)
melted_test=np.array([(k,(CASSCF.loc[k].values+v['pred'])[0]) for k,v in test_E2.items()]).astype(float)

# %%
mean_absolute_error(CASPT2.values,pd.DataFrame(np.vstack([melted_train,melted_test]),columns=['angle','CASPT2']).set_index('angle').sort_index().values)
# Out:
# np.float64(0.004241189851878789)

# %%
CASPT2.mean()
# Out:
# O3/CASPT2.csv   -224.423943
# dtype: float64

# %%
pal=sns.color_palette('Paired',2)
plt.plot(CASPT2.index,CASPT2.values,'k')
plt.scatter(melted_train[:,0],melted_train[:,1],color=pal[0],label='Train')
plt.scatter(melted_test[:,0],melted_test[:,1],color=pal[1],label='Test')
plt.legend()
plt.show()

# %%
mean_absolute_percentage_error([v['true'] for k,v in train_E2.items()],[v['pred'] for k,v in train_E2.items()])
# Out:
# np.float64(0.0395078415022053)

# %%
mean_absolute_percentage_error([v['true'] for k,v in test_E2.items()],[v['pred'] for k,v in test_E2.items()])
# Out:
# np.float64(0.04714193215952623)

# %%
mean_absolute_error([v['true'] for k,v in test_E2.items()],[v['pred'] for k,v in test_E2.items()])
# Out:
# np.float64(0.004606865303778798)

# %%
mean_absolute_error([v['true'] for k,v in train_E2.items()],[v['pred'] for k,v in train_E2.items()])
# Out:
# np.float64(0.0038750647896671733)

# %%
sns.scatterplot(data=pd.DataFrame.from_dict(test_E2).T,x='true',y='pred')
sns.scatterplot(data=pd.DataFrame.from_dict(train_E2).T,x='true',y='pred')
sns.lineplot(data=pd.DataFrame.from_dict(train_E2).T,x='true',y='true')
# Out:
# <Axes: xlabel='true', ylabel='pred'>
# [CV 1/5; 1/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 1/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.110 total time=   0.1s
# [CV 5/5; 3/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 5/5; 3/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.153 total time=   0.0s
# [CV 5/5; 4/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 4/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.154 total time=   0.0s
# [CV 5/5; 5/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 5/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.154 total time=   0.1s
# [CV 1/5; 8/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 1/5; 8/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.136 total time=   0.0s
# [CV 1/5; 10/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 10/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.073 total time=   0.2s
# [CV 5/5; 13/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 13/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.149 total time=   0.2s
# [CV 1/5; 14/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 1/5; 14/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.076 total time=   0.2s
# [CV 5/5; 19/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 5/5; 19/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.153 total time=   0.4s
# [CV 1/5; 20/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 1/5;