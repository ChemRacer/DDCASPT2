# %%
# For data generation
import sys
# !{sys.executable} -m pip install xgboost --upgrade
import shutil
import os
import numpy as np
from glob import glob
import re
import pandas as pd
import pickle
#random
from time import perf_counter

# sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,root_mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.kernel_ridge import KernelRidge
from sklearn.model_selection import GridSearchCV


#Plotting
import seaborn as sns
sns.set_style()
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 200

import warnings
# warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 


from tqdm.auto import tqdm
# from tqdm.notebook import tqdm_notebook as tqdm

# %%
with open('test_ind.pickle', 'rb') as handle:
    test_ind = pickle.load(handle)

with open('train_ind.pickle', 'rb') as handle:
    train_ind = pickle.load(handle)
    
print(len(train_ind),len(test_ind))
# Out:
# 76 76

# %%
feat_name=['From_Same_Orbital', 'pair_energy', 'coulomb', 'screen1_1', 'screen1_2',
       'screen1_3', 'screen1_4', 'screen2_1', 'screen2_2', 'screen2_3',
       'screen2_4', 'eijab_1', 'eijab_2', 'eijab_3', 'eijab_4', 'screenvirt_1',
       'screenvirt_2', 'screenvirt_3', 'screenvirt_4', 'Fr1', 'Fr2', 'Fr3',
       'Fr4', 'Fs1', 'Fs2', 'Fs3', 'Fs4', 'occr1', 'occr2', 'occr3', 'occr4',
       'occs1', 'occs2', 'occs3', 'occs4', 'SCFFr1', 'SCFFr2', 'SCFFr3',
       'SCFFr4', 'SCFFs1', 'SCFFs2', 'SCFFs3', 'SCFFs4', 'SCFOCCr1',
       'SCFOCCr2', 'SCFOCCr3', 'SCFOCCr4', 'SCFOCCs1', 'SCFOCCs2', 'SCFOCCs3',
       'SCFOCCs4', 'hrr1', 'hrr2', 'hrr3', 'hrr4', 'hss1', 'hss2', 'hss3',
       'hss4', 'hpp', 'hqq', 'Fp', 'Fq', 'occp', 'occq', 'SCFFp', 'SCFFq',
       'SCFOCCp', 'SCFOCCq']

# feat_name=['occs3',
#  'SCFOCCs2',
#  'SCFOCCs1',
#  'screen2_1',
#  'SCFOCCp',
#  'hss4',
#  'hrr1',
#  'Fs2',
#  'occq',
#  'screenvirt_4',
#  'SCFFs2',
#  'hrr3',
#  'SCFFr1',
#  'screenvirt_2',
#  'screenvirt_3',
#  'SCFFs4',
#  'hss2',
#  'screen1_2',
#  'hrr4',
#  'screen1_3',
#  'Fp',
#  'Fr1',
#  'screenvirt_1',
#  'occs4',
#  'screen2_4',
#  'SCFFr2',
#  'eijab_2',
#  'screen2_3',
#  'SCFFs1',
#  'eijab_4',
#  'Fq',
#  'hss1',
#  'SCFFr4',
#  'occs2',
#  'occp',
#  'screen1_4',
#  'eijab_1',
#  'hpp',
#  'pair_energy',
#  'hrr2',
#  'hqq',
#  'SCFFr3',
#  'occs1',
#  'Fr2',
#  'eijab_3',
#  'SCFOCCq',
#  'SCFOCCs4',
#  'Fs3',
#  'Fs1',
#  'From_Same_Orbital',
#  'hss3',
#  'Fs4',
#  'SCFOCCs3',
#  'Fr4',
#  'screen2_2',
#  'screen1_1',
#  'Fr3',
#  'SCFFs3']

# feat_name=['SCFFs3',
#  'hrr3',
#  'screen1_1',
#  'SCFOCCs2',
#  'hpp',
#  'SCFOCCs3',
#  'hss4',
#  'screen2_2',
#  'SCFOCCq',
#  'hss1',
#  'screenvirt_3',
#  'SCFFs4',
#  'SCFFr4',
#  'SCFOCCs1',
#  'SCFFr3',
#  'hss2',
#  'screen2_4',
#  'screenvirt_2',
#  'SCFFs2',
#  'hss3',
#  'hqq',
#  'hrr4',
#  'hrr1',
#  'screen1_3',
#  'SCFOCCs4',
#  'SCFFr1',
#  'SCFFs1',
#  'hrr2',
#  'SCFFr2',
#  'screen1_4',
#  'screen2_1',
#  'screenvirt_1',
#  'screen1_2',
#  'SCFOCCp',
#  'screen2_3',
#  'screenvirt_4']

# %%
train_X=[]
train_y = []

test_X=[]
test_y = []

nam='O3/fixed_feats.pickle'
trydf=pd.read_pickle(nam).astype(float)[feat_name]  
new_index_level_0 = [u.split('/')[1].split('_')[1] for u in trydf.index.get_level_values(0)]
new_index = pd.MultiIndex.from_arrays(
    [new_index_level_0] + [trydf.index.get_level_values(i) for i in range(1, trydf.index.nlevels)],
    names=trydf.index.names
)
trydf.index = new_index

# trydf.index = pd.MultiIndex.from_arrays([(u.split('/')[1].split('_')[1],v) for u,v in trydf.index])

for i in train_ind:
    print(i)
    train_X.append(trydf.loc[f"{i:.2f}"].values)
for j in test_ind: 
    test_X.append(trydf.loc[f"{j:.2f}"].values)
# Out:
# 106.0
# 107.0
# 108.0
# 109.0
# 110.0
# 111.0
# 112.0
# 113.0
# 114.0
# 115.0
# 116.0
# 117.0
# 118.0
# 119.0
# 120.0
# 121.0
# 122.0
# 123.0
# 124.0
# 125.0
# 126.0
# 127.0
# 128.0
# 129.0
# 130.0
# 131.0
# 132.0
# 133.0
# 134.0
# 135.0
# 136.0
# 137.0
# 138.0
# 139.0
# 140.0
# 141.0
# 142.0
# 143.0
# 144.0
# 145.0
# 146.0
# 147.0
# 148.0
# 149.0
# 150.0
# 151.0
# 152.0
# 153.0
# 154.0
# 155.0
# 156.0
# 157.0
# 158.0
# 159.0
# 160.0
# 161.0
# 162.0
# 163.0
# 164.0
# 165.0
# 166.0
# 167.0
# 168.0
# 169.0
# 170.0
# 171.0
# 172.0
# 173.0
# 174.0
# 175.0
# 176.0
# 177.0
# 178.0
# 179.0
# 180.0
# 181.0

# %%
trydf
# Out:
#               From_Same_Orbital   pair_energy   coulomb  screen1_1  screen1_2  \
# 161.00 A1_A1                1.0           NaN  0.510421   0.374993   0.374993
#        A1_A2                0.0  4.326812e+14  0.448914   0.189855   0.374993
#        A1_A3                0.0           NaN  0.426528   0.374993   0.189855
#        A2_A1                0.0  4.326812e+14  0.448914   0.348033   0.443104
#        A2_A2                1.0           NaN  0.558877   0.450784   0.450784
# ...                         ...           ...       ...        ...        ...
# 158.00 I9_I5                0.0 -7.304928e-02  0.474882   0.459991   0.459991
#        I9_I6                0.0 -2.853774e-01  0.477946   0.372528   0.372528
#        I9_I7                0.0 -1.850776e-03  0.431135   0.424623   0.424623
#        I9_I8                0.0 -6.334389e-03  0.433404   0.459991   0.459991
#        I9_I9                1.0 -2.248401e+00  0.498277   0.462871   0.468016
#
#               screen1_3  screen1_4  screen2_1  screen2_2  screen2_3  ...  \
# 161.00 A1_A1   0.439328   0.341702   0.374993   0.374993   0.439328  ...
#        A1_A2   0.232863   0.232863   0.558877   0.558877   0.519129  ...
#        A1_A3   0.374993   0.232863   0.567465   0.567465   0.567465  ...
#        A2_A1   0.450784   0.450784   0.510421   0.374993   0.374993  ...
#        A2_A2   0.450784   0.443104   0.450784   0.450784   0.450784  ...
# ...                 ...        ...        ...        ...        ...  ...
# 158.00 I9_I5   0.341279   0.341279   0.475680   0.475680   0.475680  ...
#        I9_I6   0.482271   0.482271   0.458270   0.458270   0.458270  ...
#        I9_I7   0.372528   0.372528   0.513579   0.513579   0.513579  ...
#        I9_I8   0.341279   0.341279   0.475945   0.475945   0.475945  ...
#        I9_I9   0.465083   0.433430   0.462871   0.468016   0.462871  ...
#
#                 hpp    hqq      Fp       Fq      occp      occq    SCFFp  \
# 161.00 A1_A1 -11.12 -11.12 -0.7333 -0.73330  1.999491  1.999491  0.00000
#        A1_A2 -11.12 -11.12 -0.7333 -0.45510  1.999491  1.527626  0.00000
#        A1_A3 -11.12 -11.12 -0.7333 -0.03768  1.999491  0.472883  0.00000
#        A2_A1 -12.09 -12.09 -0.4551 -0.73330  1.527626  1.999491  0.00000
#        A2_A2 -12.09 -12.09 -0.4551 -0.45510  1.527626  1.527626  0.00000
# ...             ...    ...     ...      ...       ...       ...      ...
# 158.00 I9_I5 -11.66 -11.66 -0.6081 -1.44800  2.000000  2.000000 -0.62523
#        I9_I6 -11.66 -11.66 -0.6081 -1.05400  2.000000  2.000000 -0.62523
#        I9_I7 -11.66 -11.66 -0.6081 -0.79620  2.000000  2.000000 -0.62523
#        I9_I8 -11.66 -11.66 -0.6081 -0.78080  2.000000  2.000000 -0.62523
#        I9_I9 -11.66 -11.66 -0.6081 -0.60810  2.000000  2.000000 -0.62523
#
#                  SCFFq   SCFOCCp   SCFOCCq
# 161.00 A1_A1  0.000000  1.999491  1.999491
#        A1_A2  0.000000  1.999491  1.527626
#        A1_A3  0.000000  1.999491  0.472883
#        A2_A1  0.000000  1.527626  1.999491
#        A2_A2  0.000000  1.527626  1.527626
# ...                ...       ...       ...
# 158.00 I9_I5 -1.447832  2.000000  2.000000
#        I9_I6 -1.044865  2.000000  2.000000
#        I9_I7 -0.803786  2.000000  2.000000
#        I9_I8 -0.764665  2.000000  2.000000
#        I9_I9 -0.625230  2.000000  2.000000
#
# [14288 rows x 69 columns]

# %%
# This recover is wrong... did not account for the # of pair-energies     
recover_train=[]    
recover_test=[]    
tst_idx=0
tr_idx=0
for nidx,nam in enumerate(glob('*/fixed_targets.pickle')):
    print(nam)
    tryy=pd.read_pickle(nam).astype(float)
    Hnam=nam.split('/')[0].split('_')[0]
    for tridx,i in enumerate(train_ind):
        pairdf=tryy[f"{i:.2f}"].values
        train_y.append(pairdf)
        for k in range(len(pairdf)):
            recover_train.append((float(i),tridx,tr_idx))
            tr_idx+=1
        
    for teidx,j in enumerate(test_ind): 
        pairdf=tryy[f"{j:.2f}"].values
        test_y.append(pairdf)        
        
        for k in range(len(pairdf)):
            recover_test.append((float(j),teidx,tst_idx))
            tst_idx+=1
# Out:
# O3/fixed_targets.pickle

# %%
X_train, X_test=np.vstack(train_X).astype(float),np.vstack(test_X).astype(float)
for u,v in np.argwhere(np.isnan(X_train)):
    X_train[u,v]=0
    
for u,v in np.argwhere(np.isnan(X_test)):
    X_test[u,v]=0

# %%
y_train,y_test=np.hstack(train_y).astype(float),np.hstack(test_y).astype(float)

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (7144, 69) (7144, 69)

# %%
from xgboost import XGBRegressor
# model=XGBRegressor(reg_lambda=0.3,max_depth=100,min_child_weight=5)
# model=XGBRegressor(max_depth=100,min_child_weight=1,n_estimators=100, reg_alpha=0.001, reg_lambda=0.001)
# model.fit(X_train,y_train)
# y_pred_train=model.predict(X_train)
# y_pred_test=model.predict(X_test)
# print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
# print(f"RMSE (mEh): {root_mean_squared_error(y_train,y_pred_train)*1e3:.4f},{root_mean_squared_error(y_test,y_pred_test)*1e3:.4f}")

params = {'max_depth': [1, 10, 100],
          'n_estimators': [100, 500, 1000],
          'reg_lambda': [1e-6, 1e-3,1e-1],
          'reg_alpha': [1e-6, 1e-3,1e-1]}

model = XGBRegressor()
grid = GridSearchCV(estimator=model, 
                   param_grid=params,
                   scoring='r2', 
                   verbose=1000,n_jobs=12).fit(X_train,y_train)


gmodel=grid.best_estimator_
# gmodel.device = 'cuda:0'
y_pred_train=gmodel.predict(X_train)
y_pred_test=gmodel.predict(X_test)
print(f"R2: {r2_score(y_train,y_pred_train):.4f},{r2_score(y_test,y_pred_test):.4f}")
print(f"RMSE (mEh): {root_mean_squared_error(y_train,y_pred_train)*1e3:.4f},{root_mean_squared_error(y_test,y_pred_test)*1e3:.4f}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 5/5; 1/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 5/5; 1/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.362 total time=   0.1s
# [CV 1/5; 4/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 4/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.328 total time=   0.1s
# [CV 4/5; 4/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 4/5; 4/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.441 total time=   0.1s
# [CV 4/5; 5/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 4/5; 5/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.441 total time=   0.1s
# [CV 2/5; 7/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 7/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.473 total time=   0.1s
# [CV 1/5; 9/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 1/5; 9/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.335 total time=   0.1s
# [CV 3/5; 10/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 3/5; 10/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.784 total time=   0.2s
# [CV 4/5; 12/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1
# [CV 4/5; 12/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.1;, score=0.739 total time=   0.2s
# [CV 3/5; 14/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 3/5; 14/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.783 total time=   0.2s
# [CV 2/5; 16/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 16/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.768 total time=   0.2s
# [CV 3/5; 16/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 3/5; 16/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.772 total time=   0.2s
# [CV 1/5; 21/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 1/5; 21/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.436 total time=   0.4s
# [CV 2/5; 21/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 2/5; 21/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.852 total time=   0.4s
# [CV 1/5; 25/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06
# [CV 1/5; 25/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06;, score=0.529 total time=   0.4s
# [CV 2/5; 25/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 25/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06;, score=0.836 total time=   0.4s
# [CV 3/5; 27/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 27/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.836 total time=   0.4s
# [CV 4/5; 27/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 27/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.811 total time=   0.4s
# [CV 3/5; 31/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 3/5; 31/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.984 total time=   0.5s
# [CV 4/5; 31/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 4/5; 31/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.983 total time=   0.6s
# [CV 3/5; 35/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 3/5; 35/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.988 total time=   0.3s
# [CV 4/5; 35/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 4/5; 35/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.983 total time=   0.3s
# [CV 5/5; 37/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 5/5; 37/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.574 total time=   0.7s
# [CV 1/5; 38/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 1/5; 38/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.936 total time=   0.6s
# [CV 2/5; 41/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 2/5; 41/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.985 total time=   0.6s
# [CV 1/5; 43/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 1/5; 43/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.869 total time=   0.6s
# [CV 2/5; 45/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 2/5; 45/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.987 total time=   0.6s
# [CV 1/5; 48/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 1/5; 48/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.936 total time=   1.1s
# [CV 5/5; 50/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 50/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001;, score=0.577 total time=   1.1s
# [CV 1/5; 54/81] START max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 1/5; 54/81] END max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.867 total time=   0.9s
# [CV 5/5; 56/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 56/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001;, score=0.575 total time=   1.7s
# [CV 1/5; 59/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 1/5; 59/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.929 total time=   0.9s
# [CV 4/5; 60/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 60/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.981 total time=   0.8s
# [CV 4/5; 63/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 63/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.980 total time=   0.4s
# [CV 4/5; 65/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 4/5; 65/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.980 total time=   1.5s
# [CV 1/5; 67/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 67/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.929 total time=   0.8s
# [CV 1/5; 69/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 1/5; 69/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.927 total time=   0.9s
# [CV 3/5; 70/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 3/5; 70/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.987 total time=   0.6s
# [CV 4/5; 72/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 72/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.980 total time=   1.1s
# [CV 2/5; 75/81] START max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1
# [CV 2/5; 75/81] END max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.1;, score=0.982 total time=   1.8s
# [CV 5/5; 77/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 77/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001;, score=0.578 total time=   1.5s
# /home/grierjones/miniconda3/envs/DDGNN/lib/python3.10/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# R2: 0.9983,0.9663
# RMSE (mEh): 0.7412,3.2916

# %%
pairedcp=sns.color_palette('Paired')

# %%
np.max(y_pred_test)*1e3
# Out:
# np.float32(0.45512137)

# %%
font=12
plt.rc('font', size=font)          # controls default text sizes
plt.rc('axes', titlesize=font)     # fontsize of the axes title
plt.rc('axes', labelsize=font)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=font)    # fontsize of the tick labels
plt.rc('ytick', labelsize=font)    # fontsize of the tick labels
plt.rc('legend', fontsize=font)    # legend fontsize
plt.rc('figure', titlesize=font)  # fontsize of the figure title
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,6))
scale=1e-1
ax1.set_title('Train')
ax1.scatter(1e3*y_train,1e3*y_pred_train,label="R$^{2}$="+f'{r2_score(y_train,y_pred_train):.2f}\nMAE={1e3*mean_absolute_error(y_train,y_pred_train):.4f}'+" mE$_{h}$",color=pairedcp[0],edgecolors='k')
ax1.plot(np.arange(-200,200),np.arange(-200,200),'k-')
ax1.set_xlim(-110,10)
ax1.set_ylim(-110,10)
ax1.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax1.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax1.legend(loc=2)


ax2.set_title('Test')
ax2.scatter(1e3*y_test,1e3*y_pred_test,label="R$^{2}$="+f'{r2_score(y_test,y_pred_test):.2f}\nMAE={1e3*mean_absolute_error(y_test,y_pred_test):.4f}'+" mE$_{h}$",color=pairedcp[1],edgecolors='k')
ax2.plot(np.arange(-200,200),np.arange(-200,200),'k-')
ax2.set_xlim(-110,10)
ax2.set_ylim(-110,10)
ax2.set_xlabel('Calculated Pair-Energies (mE$_{h}$)')
ax2.set_ylabel('Predicted Pair-Energies (mE$_{h}$)')
ax2.legend()
if os.path.exists('images')==False:
    os.mkdir('images')
plt.tight_layout()
plt.savefig('images/O3_parity.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
testdct=[np.vstack((y_test[np.array(recover_test)[np.array(recover_test)[:,1].astype(int)==i][:,2].astype(int)],y_pred_test[np.array(recover_test)[np.array(recover_test)[:,1].astype(int)==i][:,2].astype(int)])) for i in np.unique(np.array(recover_test)[:,1].astype(int))]

test_errors=mean_absolute_error(np.hstack(testdct)[0],np.hstack(testdct)[1])*1e3

# %%
traindct=[np.vstack((y_train[np.array(recover_train)[np.array(recover_train)[:,1].astype(int)==i][:,2].astype(int)],y_pred_train[np.array(recover_train)[np.array(recover_train)[:,1].astype(int)==i][:,2].astype(int)])) for i in np.unique(np.array(recover_train)[:,1].astype(int))]

train_errors=mean_absolute_error(np.hstack(traindct)[0],np.hstack(traindct)[1])*1e3

# %%
CASSCF=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/CASSCF.csv')],axis=1)
CASPT2=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/CASPT2.csv')],axis=1)
E2=pd.concat([pd.read_csv(i,index_col=1).drop(columns=['Unnamed: 0']).rename(columns={'energy':i.split('_')[0]}) for i in glob('*/E2.csv')],axis=1)    

# CASSCF.index=[f'{int(i)}' for i in CASSCF.index]
# CASPT2.index=[f'{int(i)}' for i in CASPT2.index]
# E2.index=[f'{int(i)}' for i in E2.index]

# %%
test_E2={np.unique(np.array(recover_test)[:,0])[idx]:{'true':sum(u),'pred':sum(v)} for idx,(u,v) in enumerate(testdct)}
train_E2={np.unique(np.array(recover_train)[:,0])[idx]:{'true':sum(u),'pred':sum(v)} for idx,(u,v) in enumerate(traindct)}

# %%
melted_train=np.array([(k,(CASSCF.loc[k].values+v['pred'])[0]) for k,v in train_E2.items()]).astype(float)
melted_test=np.array([(k,(CASSCF.loc[k].values+v['pred'])[0]) for k,v in test_E2.items()]).astype(float)

# %%
f"{mean_absolute_error(CASPT2.values,pd.DataFrame(np.vstack([melted_train,melted_test]),columns=['angle','CASPT2']).set_index('angle').sort_index().values)*1e3:.4f}"
# Out:
# '7.3681'

# %%
checktest = pd.DataFrame.from_dict(test_E2).T

# %%
(checktest['true']-checktest['pred']).abs().sort_values().iloc[-9:]
# Out:
# 163.5    0.018052
# 106.5    0.027437
# 125.5    0.035494
# 152.5    0.040676
# 168.5    0.042671
# 111.5    0.043443
# 117.5    0.108938
# 114.5    0.114262
# 124.5    0.124377
# dtype: float64

# %%
mean_absolute_error(CASPT2.loc[melted_train[:,0]],melted_train[:,1])
# Out:
# np.float64(0.0025315710479098265)

# %%
train_error_notes="Train\nR$^{2}$="+f"{r2_score(CASPT2.loc[melted_train[:,0]],melted_train[:,1]):.4f}\nMAE: {mean_absolute_error(CASPT2.loc[melted_train[:,0]],melted_train[:,1])*1e3:.4f}"+" mE$_{h}$\n"
test_error_notes="Test\nR$^{2}$="+f"{r2_score(CASPT2.loc[melted_test[:,0]],melted_test[:,1]):.4f}\nMAE: {mean_absolute_error(CASPT2.loc[melted_test[:,0]],melted_test[:,1])*1e3:.4f}"+" mE$_{h}$"
# "Test: R$^{2}$"+f"{r2_score(CASPT2.loc[melted_test[:,0]],melted_test[:,1])}:.2f"

# %%
# pal=sns.color_palette('Paired',2)
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10,5))
ax2.plot(CASPT2.index,CASPT2.values,'k',label='Calculated')
ax2.scatter(melted_train[:,0],melted_train[:,1],label='Train',color=pairedcp[0],edgecolors='k')
ax2.scatter(melted_test[:,0],melted_test[:,1],label='Test',color=pairedcp[1],edgecolors='k')
ax2.legend()
ax2.set_ylim(-225.35,-225.1)
ax2.set_xlim(100,190)
ax2.set_ylabel('CASPT2 Energy (E$_{h}$)')
ax2.set_xlabel(r"Angle ($\circ$)")

ax1.text(-225.22,-225.34,train_error_notes+test_error_notes)
ax1.plot(np.arange(-300,300),np.arange(-300,300),'k')
ax1.scatter(CASPT2.loc[melted_train[:,0]],melted_train[:,1],label='Train',color=pairedcp[0],edgecolors='k')
ax1.scatter(CASPT2.loc[melted_test[:,0]],melted_test[:,1],label='Test',color=pairedcp[1],edgecolors='k')
ax1.set_xlim(-225.35,-225.1)
ax1.set_ylim(-225.35,-225.1)
ax1.set_ylabel('Predicted CASPT2 Energy (E$_{h}$)')
ax1.set_xlabel('Calculated CASPT2 Energy (E$_{h}$)')
ax1.legend()
fig.suptitle('O$_{3}$ ANO-RCC-VTZP')
plt.tight_layout()
plt.savefig('images/O3_VTZP_CASPT2.png',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# [CV 2/5; 1/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 2/5; 1/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.476 total time=   0.1s
# [CV 3/5; 3/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1
# [CV 3/5; 3/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.1;, score=0.496 total time=   0.1s
# [CV 2/5; 4/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 2/5; 4/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.475 total time=   0.1s
# [CV 1/5; 5/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 1/5; 5/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.328 total time=   0.1s
# [CV 2/5; 6/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 2/5; 6/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.475 total time=   0.1s
# [CV 4/5; 7/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 4/5; 7/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.438 total time=   0.1s
# [CV 4/5; 9/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 9/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.438 total time=   0.1s
# [CV 5/5; 11/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 11/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.666 total time=   0.2s
# [CV 1/5; 13/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 13/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.525 total time=   0.2s
# [CV 3/5; 15/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 3/5; 15/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.783 total time=   0.2s
# [CV 4/5; 15/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 4/5; 15/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.738 total time=   0.2s
# [CV 2/5; 20/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 2/5; 20/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001;, score=0.852 total time=   0.4s
# [CV 3/5; 20/81] START max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 3/5; 20/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001;, score=0.845 total time=   0.4s
# [CV 5/5; 23/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 23/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.001;, score=0.735 total time=   0.4s
# [CV 1/5; 24/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 1/5; 24/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.475 total time=   0.4s
# [CV 4/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 4/5; 26/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.812 total time=   0.4s
# [CV 5/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 5/5;
_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 1/5; 20/81] END max_depth=1, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001;, score=0.449 total time=   0.7s
# [CV 2/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 2/5; 26/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.836 total time=   0.7s
# [CV 3/5; 26/81] START max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 3/5; 26/81] END max_depth=1, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.837 total time=   0.7s
# [CV 4/5; 32/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 4/5; 32/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.983 total time=   0.8s
# [CV 5/5; 32/81] START max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 32/81] END max_depth=10, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.577 total time=   0.5s
# [CV 3/5; 37/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 3/5; 37/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.984 total time=   0.7s
# [CV 4/5; 37/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 4/5; 37/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.983 total time=   0.6s
# [CV 5/5; 41/81] START max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 41/81] END max_depth=10, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.577 total time=   0.6s
# [CV 2/5; 43/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 43/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.988 total time=   0.6s
# [CV 2/5; 46/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 2/5; 46/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.985 total time=   1.2s
# [CV 2/5; 49/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 2/5; 49/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.985 total time=   1.1s
# [CV 5/5; 51/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 5/5; 51/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.585 total time=   1.0s
# [CV 2/5; 55/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 2/5; 55/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.981 total time=   1.8s
# [CV 5/5; 58/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 58/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.577 total time=   1.3s
# [CV 2/5; 61/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 61/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.987 total time=   0.6s
# [CV 3/5; 63/81] START max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 63/81] END max_depth=100, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1;, score=0.987 total time=   0.6s
# [CV 5/5; 65/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 65/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.575 total time=   2.0s
# [CV 4/5; 68/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001
# [CV 4/5; 68/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.001;, score=0.981 total time=   1.3s
# [CV 4/5; 71/81] START max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001
# [CV 4/5; 71/81] END max_depth=100, n_estimators=500, reg_alpha=0.1, reg_lambda=0.001;, score=0.980 total time=   0.8s
# [CV 5/5; 74/81] START max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 74/81] END max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=0.001;, score=0.575 total time=   1.6s
# [CV 1/5; 76/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 76/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.929 total time=   1.0s
# [CV 3/5; 78/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1
# [CV 3/5; 78/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=0.1;, score=0.985 total time=   1.0s
# [CV 2/5; 80/81] START max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001
# [CV 2/5; 80/81] END max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.001;, score=0.987 total time=   0.6s
# [CV 4/5; 81/81] START max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 4/5; 81/81] END max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.980 total time=   0.6s
# [CV 1/5; 1/81] START max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 1/81] END max_depth=1, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.328 total time=   0.1s
# [CV 5/5; 5/81] START max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001
# [CV 5/5; 5/81] END max_depth=1, n_estimators=100, reg_alpha=0.001, reg_lambda=0.001;, score=0.362 total time=   0.1s
# [CV 1/5; 8/81] START max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001
# [CV 1/5; 8/81] END max_depth=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.001;, score=0.335 total time=   0.1s
# [CV 5/5; 10/81] START max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 5/5; 10/81] END max_depth=1, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.666 total time=   0.4s
# [CV 5/5; 13/81] START max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 13/81] END max_depth=1, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.666 total time=   0.4s
# [CV 2/5; 18/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 2/5; 18/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.770 total time=   0.4s
# [CV 3/5; 18/81] START max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1
# [CV 3/5; 18/81] END max_depth=1, n_estimators=500, reg_alpha=0.1, reg_lambda=0.1;, score=0.772 total time=   0.4s
# [CV 4/5; 22/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 4/5; 22/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.830 total time=   0.7s
# [CV 5/5; 22/81] START max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 5/5; 22/81] END max_depth=1, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.735 total time=   0.7s
# [CV 3/5; 29/81] START max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001
# [CV 3/5; 29/81] END max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001;, score=0.983 total time=   0.6s
# [CV 4/5; 29/81] START max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001
# [CV 4/5; 29/81] END max_depth=10, n_estimators=100, reg_alpha=1e-06, reg_lambda=0.001;, score=0.984 total time=   0.8s
# [CV 2/5; 34/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 2/5; 34/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.988 total time=   0.4s
# [CV 3/5; 34/81] START max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06
# [CV 3/5; 34/81] END max_depth=10, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-06;, score=0.988 total time=   0.4s
# [CV 4/5; 38/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 4/5; 38/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.984 total time=   1.0s
# [CV 5/5; 38/81] START max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001
# [CV 5/5; 38/81] END max_depth=10, n_estimators=500, reg_alpha=1e-06, reg_lambda=0.001;, score=0.570 total time=   0.9s
# [CV 4/5; 43/81] START max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06
# [CV 4/5; 43/81] END max_depth=10, n_estimators=500, reg_alpha=0.1, reg_lambda=1e-06;, score=0.983 total time=   0.6s
# [CV 3/5; 46/81] START max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 3/5; 46/81] END max_depth=10, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.984 total time=   1.2s
# [CV 3/5; 49/81] START max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 3/5; 49/81] END max_depth=10, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.984 total time=   1.1s
# [CV 3/5; 52/81] START max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06
# [CV 3/5; 52/81] END max_depth=10, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06;, score=0.988 total time=   0.8s
# [CV 1/5; 55/81] START max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 1/5; 55/81] END max_depth=100, n_estimators=100, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.936 total time=   1.7s
# [CV 1/5; 58/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06
# [CV 1/5; 58/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=1e-06;, score=0.929 total time=   1.3s
# [CV 3/5; 60/81] START max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1
# [CV 3/5; 60/81] END max_depth=100, n_estimators=100, reg_alpha=0.001, reg_lambda=0.1;, score=0.985 total time=   1.0s
# [CV 3/5; 64/81] START max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 3/5; 64/81] END max_depth=100, n_estimators=500, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.977 total time=   1.9s
# [CV 3/5; 67/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06
# [CV 3/5; 67/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=1e-06;, score=0.982 total time=   1.4s
# [CV 5/5; 69/81] START max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1
# [CV 5/5; 69/81] END max_depth=100, n_estimators=500, reg_alpha=0.001, reg_lambda=0.1;, score=0.578 total time=   1.0s
# [CV 5/5; 73/81] START max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06
# [CV 5/5; 73/81] END max_depth=100, n_estimators=1000, reg_alpha=1e-06, reg_lambda=1e-06;, score=0.575 total time=   2.2s
# [CV 3/5; 76/81] START max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06
# [CV 3/5; 76/81] END max_depth=100, n_estimators=1000, reg_alpha=0.001, reg_lambda=1e-06;, score=0.982 total time=   1.6s
# [CV 1/5; 79/81] START max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06
# [CV 1/5; 79/81] END max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=1e-06;, score=0.862 total time=   1.0s
# [CV 5/5; 81/81] START max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1
# [CV 5/5; 81/81] END max_depth=100, n_estimators=1000, reg_alpha=0.1, reg_lambda=0.1;, score=0.596 total time=   0.6s

# %%
mean_absolute_percentage_error([v['true'] for k,v in train_E2.items()],[v['pred'] for k,v in train_E2.items()])
# Out:
# np.float64(0.003657246897341674)

# %%
mean_absolute_percentage_error([v['true'] for k,v in test_E2.items()],[v['pred'] for k,v in test_E2.items()])
# Out:
# np.float64(0.017658145478538202)

# %%
mean_absolute_error([v['true'] for k,v in test_E2.items()],[v['pred'] for k,v in test_E2.items()])
# Out:
# np.float64(0.012204794346878512)

# %%
mean_absolute_error([v['true'] for k,v in train_E2.items()],[v['pred'] for k,v in train_E2.items()])
# Out:
# np.float64(0.0025311532455930437)

# %%
sns.scatterplot(data=pd.DataFrame.from_dict(test_E2).T,x='true',y='pred')
sns.scatterplot(data=pd.DataFrame.from_dict(train_E2).T,x='true',y='pred')
sns.lineplot(data=pd.DataFrame.from_dict(train_E2).T,x='true',y='true')
# Out:
# <Axes: xlabel='true', ylabel='pred'>
