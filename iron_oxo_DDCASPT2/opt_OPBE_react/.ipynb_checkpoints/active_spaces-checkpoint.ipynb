# %%
# Suppress PySCF warning...
import pyscf
pyscf.__config__.B3LYP_WITH_VWN5 = False

# %%
from pathlib import Path

# The Mole class is used to define molecular information in PySCF.
from pyscf.gto import Mole

# logger contains definitions of verbosity levels for PySCF.
from pyscf.lib import logger

# Functionality for (state-averaged) CASSCF.
from pyscf.mcscf import CASSCF, state_average_mix
from pyscf.fci.direct_spin1 import FCISolver
from pyscf.fci.addons import fix_spin

# Wrapper functions to perform selection for variable and fixed active space sizes
from asf.wrapper import find_from_mol, find_from_scf, sized_space_from_mol, sized_space_from_scf

# Various utility functions...
from asf.utility import compare_active_spaces, show_mos_grid, pictures_Jmol

from glob import glob
import numpy as np
import os, sys
# !{sys.executable} -m pip install tqdm
from tqdm import tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.5

# %%
struc_size = {}
for i in glob("*xyz"):
    with open(i,'r') as f:
        size=f.readlines()[0]
    struc_size[i]=int(size.strip())

# %%
mol=Mole(atom='19.xyz', basis="def2-SVP", charge=2, spin=2, verbose=logger.INFO).build()
active_space = find_from_mol(mol)
# Out:
# System: uname_result(system='Linux', node='debian', release='6.10.12-amd64', version='#1 SMP PREEMPT_DYNAMIC Debian 6.10.12-1 (2024-10-01)', machine='x86_64')  Threads 16
# Python 3.11.10 | packaged by conda-forge | (main, Sep 30 2024, 18:08:57) [GCC 13.3.0]
# numpy 1.26.4  scipy 1.10.1  h5py 3.12.1
# Date: Mon Oct  7 11:33:44 2024
# PySCF version 2.7.0
# PySCF path  /home/grierjones/miniconda3/envs/asfbase/lib/python3.11/site-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 14
# [INPUT] num. electrons = 72
# [INPUT] charge = 2
# [INPUT] spin (= nelec alpha-beta = 2S) = 2
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 O      1.716330000000   0.133070000000   0.000070000000 AA    3.243393639375   0.251465855396   0.000132280829 Bohr   0.0
# [INPUT]  2 Fe     0.140110000000   0.002050000000   0.000010000000 AA    0.264769527313   0.003873938555   0.000018897261 Bohr   0.0
# [INPUT]  3 O     -0.003010000000   1.014110000000  -1.734620000000 AA   -0.005688075635   1.916390160183  -3.277956730193 Bohr   0.0
# [INPUT]  4 H     -0.734450000000   1.581600000000  -2.036430000000 AA   -1.387909352187   2.988790838612  -3.848294971848 Bohr   0.0
# [INPUT]  5 O     -1.929440000000  -0.182060000000  -0.000070000000 AA   -3.646113173781  -0.344043538238  -0.000132280829 Bohr   0.0
# [INPUT]  6 H     -2.491480000000  -0.346510000000  -0.776760000000 AA   -4.708214844831  -0.654808999423  -1.467863664517 Bohr   0.0
# [INPUT]  7 O      0.280780000000  -1.984990000000   0.000320000000 AA    0.530597301255  -3.751087460000   0.000604712360 Bohr   0.0
# [INPUT]  8 H      1.139200000000  -2.447480000000   0.000450000000 AA    2.152776001105  -4.625066895350   0.000850376756 Bohr   0.0
# [INPUT]  9 H     -0.433630000000  -2.645290000000   0.000400000000 AA   -0.819441939395  -4.998873620051   0.000755890450 Bohr   0.0
# [INPUT] 10 O     -0.003190000000   1.014670000000   1.734290000000 AA   -0.006028226337   1.917448406812   3.277333120572 Bohr   0.0
# [INPUT] 11 H      0.805840000000   1.305350000000   2.195640000000 AA    1.522816900220   2.466753996701   4.149158268140 Bohr   0.0
# [INPUT] 12 H     -0.734670000000   1.582250000000   2.035860000000 AA   -1.388325091934   2.990019160593   3.847217827957 Bohr   0.0
# [INPUT] 13 H      0.806070000000   1.304630000000  -2.195980000000 AA    1.523251537228   2.465393393891  -4.149800775022 Bohr   0.0
# [INPUT] 14 H     -2.491540000000  -0.346230000000   0.776630000000 AA   -4.708328228399  -0.654279876108   1.467618000121 Bohr   0.0
#
# nuclear repulsion = 518.843748633796
# number of shells = 65
# number of NR pGTOs = 249
# number of NR cGTOs = 141
# basis = def2-SVP
# ecp = {}
# CPU time:         1.03
#
# --------------------------------------------------------------------------------
# Calculating UHF orbitals
# --------------------------------------------------------------------------------
#
# -> Initiating a UHF calculation.
#
#
# ******** <class 'pyscf.scf.uhf.UHF'> ********
# method = UHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpmhi28hrk
# max_memory 4000 MB (current use 195 MB)
# number electrons alpha = 37  beta = 35
# Set gradient conv threshold to 3.16228e-05
# init E= -1638.76225249378
#   alpha nocc = 37  HOMO = 0.100909562450067  LUMO = 0.113080526347317
#   beta  nocc = 35  HOMO = 0.0280053628775778  LUMO = 0.0994513548747219
#
# WARN: system HOMO 0.100909562450067 >= system LUMO 0.0994513548747219
#
# cycle= 1 E= -1628.67736836615  delta_E= 10.1  |g|= 3.31  |ddm|= 5.84
#   alpha nocc = 37  HOMO = -1.18861962902399  LUMO = -1.17807943370767
#   beta  nocc = 35  HOMO = -1.28661848611764  LUMO = -1.21888986988739
#
# WARN: system HOMO -1.18187787189318 >= system LUMO -1.21888986988739
#
# cycle= 2 E= -1616.44036223954  delta_E= 12.2  |g|= 6.22  |ddm|= 8.33
#   alpha nocc = 37  HOMO = -1.08172387036284  LUMO = -1.0696098563587
#   beta  nocc = 35  HOMO = -1.07332583735121  LUMO = -1.04174026146458
# cycle= 3 E= -1628.8493269124  delta_E= -12.4  |g|= 4.34  |ddm|= 4.79
#   alpha nocc = 37  HOMO = -0.773707066717724  LUMO = -0.729452605093151
#   beta  nocc = 35  HOMO = -0.884598655809904  LUMO = -0.869520104562779
#
# WARN: system HOMO -0.727509526915648 >= system LUMO -0.869520104562779
#
# cycle= 4 E= -1631.50667029021  delta_E= -2.66  |g|= 4.11  |ddm|= 2.13
#   alpha nocc = 37  HOMO = -0.961557887019853  LUMO = -0.957042807576137
#   beta  nocc = 35  HOMO = -0.955185708607193  LUMO = -0.934062278893877
# cycle= 5 E= -1634.06037283035  delta_E= -2.55  |g|= 3.62  |ddm|= 1.69
#   alpha nocc = 37  HOMO = -0.91949491064153  LUMO = -0.843108453684086
#   beta  nocc = 35  HOMO = -0.937406642486656  LUMO = -0.850753784523239
# cycle= 6 E= -1634.32028915322  delta_E= -0.26  |g|= 3.57  |ddm|= 0.479
#   alpha nocc = 37  HOMO = -0.924509991234648  LUMO = -0.828846635277365
#   beta  nocc = 35  HOMO = -0.957213968831033  LUMO = -0.82404483135425
# cycle= 7 E= -1634.34737706479  delta_E= -0.0271  |g|= 3.58  |ddm|= 0.211
#   alpha nocc = 37  HOMO = -0.923711504236995  LUMO = -0.826062361497415
#   beta  nocc = 35  HOMO = -0.855227913562278  LUMO = -0.220171034243651
# cycle= 46 E= -1640.33956643315  delta_E= 1.1e-05  |g|= 0.000619  |ddm|= 0.0175
#   alpha nocc = 37  HOMO = -0.891661865080214  LUMO = -0.31110600492524
#   beta  nocc = 35  HOMO = -0.855120495547728  LUMO = -0.220171316399613
# cycle= 47 E= -1640.33956071472  delta_E= 5.72e-06  |g|= 0.000643  |ddm|= 0.00904
#   alpha nocc = 37  HOMO = -0.891694152471766  LUMO = -0.311097057318967
#   beta  nocc = 35  HOMO = -0.855435782861232  LUMO = -0.220170312571853
# cycle= 48 E= -1640.33956929639  delta_E= -8.58e-06  |g|= 0.000547  |ddm|= 0.0134
#   alpha nocc = 37  HOMO = -0.891657803584653  LUMO = -0.311107942810973
#   beta  nocc = 35  HOMO = -0.855241050004537  LUMO = -0.220171393677762
# cycle= 49 E= -1640.33955938955  delta_E= 9.91e-06  |g|= 0.000589  |ddm|= 0.0155
#   alpha nocc = 37  HOMO = -0.891658461069312  LUMO = -0.311102983919842
#   beta  nocc = 35  HOMO = -0.855749661975532  LUMO = -0.220171356490991
# cycle= 50 E= -1640.3395605639  delta_E= -1.17e-06  |g|= 0.000425  |ddm|= 0.00175
# SCF not converged.
# SCF energy = -1640.3395605639 after 50 cycles  <S^2> = 3.6758197  2S+1 = 3.9627363
# uhf_internal: lowest eigs of H = [0.00031716 0.03280411 0.041372  ]
# <class 'pyscf.scf.uhf.UHF'> wavefunction is stable in the internal stability analysis
# -> Calculation did not converge.
# -> Switching to Newton solver.
# -> Initiating SCF restart number 2.
#
#
#
#
# ******** <class 'pyscf.soscf.newton_ah.SecondOrderUHF'> ********
# method = SecondOrderUHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpmhi28hrk
# max_memory 4000 MB (current use 644 MB)
# number electrons alpha = 37  beta = 35
# ******** <class 'pyscf.scf.uhf.UHF'> Newton solver flags ********
# SCF tol = 1e-09
# conv_tol_grad = None
# max. SCF cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpmhi28hrk
# max_cycle_inner = 12
# max_stepsize = 0.05
# ah_start_tol = 1e+09
# ah_level_shift = 0
# ah_conv_tol = 1e-12
# ah_lindep = 1e-14
# ah_start_cycle = 1
# ah_max_cycle = 40
# ah_grad_trust_region = 2.5
# kf_interval = 4
# kf_trust_region = 5
# canonicalization = True
# max_memory 4000 MB (current use 644 MB)
# Set conv_tol_grad to 3.16228e-05
#   alpha nocc = 37  HOMO = -0.891667159987234  LUMO = -0.311123769553681
#   beta  nocc = 35  HOMO = -0.856131479201216  LUMO = -0.220172695417091
# Initial guess E= -1640.33956091825  |g|= 0.000383293
# macro= 0  E= -1640.33967726235  delta_E= -0.000116344  |g|= 0.000383293  1 KF 8 JK
# macro= 1  E= -1640.3397605964  delta_E= -8.33341e-05  |g|= 0.0066087  2 KF 8 JK
# macro= 2  E= -1640.33993928412  delta_E= -0.000178688  |g|= 0.0025359  5 KF 26 JK
# macro= 3  E= -1640.33996843932  delta_E= -2.91552e-05  |g|= 0.00473802  4 KF 21 JK
# macro= 4  E= -1640.33997477511  delta_E= -6.33579e-06  |g|= 0.000529184  4 KF 24 JK
# macro= 5  E= -1640.33998158425  delta_E= -6.80914e-06  |g|= 9.88135e-05  4 KF 29 JK
# macro= 6  E= -1640.33998158528  delta_E= -1.03137e-09  |g|= 5.35886e-05  1 KF 3 JK
# macro= 7  E= -1640.33998158528  delta_E= 9.09495e-13  |g|= 1.19784e-05  1 KF 2 JK
# Canonicalize SCF orbitals
# macro X = 8  E=-1640.33998158528  |g|= 1.19784e-05  total 23 KF 130 JK
# converged SCF energy = -1640.33998158528  <S^2> = 3.6790568  2S+1 = 3.9643697
# uhf_internal: lowest eigs of H = [0.00079021 0.03505301 0.04233521]
# <class 'pyscf.soscf.newton_ah.SecondOrderUHF'> wavefunction is stable in the internal stability analysis
# -> The calculated SCF solution is converged and stable.
#
# --------------------------------------------------------------------------------
# Calculating MP2 natural orbitals
# --------------------------------------------------------------------------------
#
# Default auxbasis def2-svp-ri is used for Fe def2-SVP
# Default auxbasis def2-svp-ri is used for H def2-SVP
# Default auxbasis def2-svp-ri is used for O def2-SVP
#
# DF-MP2 unrelaxed density calculation
#
# Calculating integrals
# Stored in files:
# /tmp/vw6yrifo
# /tmp/8xjf1fxw
#
# -> Selected initial orbital window of 30 electrons in 30 MP2 natural orbitals.
#
# --------------------------------------------------------------------------------
# Running calculation
# --------------------------------------------------------------------------------
#
# spin = 2, number of roots = 1
# total number of roots calculated = 1
#
#
# ******** CASCI flags ********
# CAS (16e+14e, 30o), ncore = 21, nvir = 90
# natorb = False
# canonicalization = True
# sorting_mo_energy = False
# max_memory 4000 (MB)
#
# ******** Block flags ********
# executable             = /home/grierjones/miniconda3/envs/asfbase/bin/block2main
# BLOCKEXE_COMPRESS_NEVPT= /home/grierjones/miniconda3/envs/asfbase/bin/block2main
# Block version          = 2.0
# mpiprefix              =
# scratchDirectory       = /tmp/tmpmvfyz3ou
# integralFile           = ./FCIDUMP
# configFile             = ./dmrg.conf
# outputFile             = ./dmrg.out
# maxIter                = 22
# scheduleSweeps         = [0, 4, 6, 8, 10]
# scheduleMaxMs          = [200, 250, 250, 250, 250]
# scheduleTols           = [0.0001, 0.0001, 1e-05, 1.0000000000000002e-06, 1e-07]
# scheduleNoises         = [0.0001, 0.0001, 1e-05, 1.0000000000000002e-06, 0.0]
# twodot_to_onedot       = 14
# tol                    = 1e-06
# maxM                   = 250
# dmrg switch tol        = 0.001
# wfnsym                 = 1
# fullrestart            = False
# num_thrds              = 16
# memory                 = 4.0
#
# Density matrix diagonal elements [1.98792283 1.98720826 1.98884015 1.98843039 1.98658714 1.98364163
#  1.98513466 1.98385577 1.98311424 1.98390461 1.98402066 1.9841715
#  1.73754116 1.10549008 1.00046874 1.00154423 0.89634193 0.26371762
#  0.01594298 0.0160354  0.01430058 0.01548684 0.01638684 0.01675926
#  0.01431395 0.01295604 0.01217751 0.01171332 0.01182275 0.00937062]
# CASCI E = -1640.62623872304  E(CI) = -146.732399327980  S^2 = 2.0000000
#
# Orbital selection for state 0:
#
#  MO    w( )    w(↑)    w(↓)    w(⇅)       S  sel
#  21   0.001   0.005   0.004   0.989   0.070
#  22   0.002   0.005   0.004   0.989   0.071
#  23   0.001   0.005   0.005   0.990   0.067
#  24   0.001   0.005   0.005   0.989   0.069
#  25   0.001   0.006   0.006   0.988   0.078
#  26   0.002   0.006   0.006   0.985   0.090
#  27   0.002   0.006   0.006   0.987   0.083
#  28   0.002   0.006   0.006   0.986   0.088
#  29   0.002   0.007   0.007   0.985   0.094
#  30   0.002   0.007   0.006   0.986   0.089
#  31   0.001   0.007   0.006   0.985   0.090
#  32   0.001   0.007   0.007   0.985   0.090
#  33   0.081   0.059   0.040   0.819   0.665    a
#  34   0.280   0.232   0.103   0.386   1.296    a
#  35   0.000   0.919   0.079   0.001   0.288    a
#  36   0.000   0.905   0.093   0.002   0.327    a
#  37   0.384   0.250   0.084   0.281   1.279    a
#  38   0.817   0.066   0.035   0.081   0.666    a
#  39   0.985   0.007   0.007   0.001   0.091
#  40   0.986   0.006   0.006   0.002   0.087
#  41   0.987   0.006   0.006   0.001   0.083
#  42   0.986   0.006   0.006   0.002   0.086
#  43   0.985   0.007   0.007   0.002   0.091
#  44   0.987   0.004   0.004   0.004   0.083
#  45   0.987   0.006   0.006   0.001   0.083
#  46   0.988   0.005   0.005   0.001   0.075
#  47   0.989   0.005   0.005   0.001   0.072
#  48   0.989   0.005   0.005   0.001   0.069
#  49   0.990   0.005   0.005   0.001   0.069
#  50   0.991   0.004   0.004   0.001   0.058
#
#
# --------------------------------------------------------------------------------
# Active space selection finished
# --------------------------------------------------------------------------------
#
# -> Selected an active space of 6 electrons in 6 orbitals.

# %%
mol.nao
# Out:
# 141

# %%
mol

# %%
dir(active_space)
# Out:
# ['DataDict',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_validate_mo_coeff',
#  '_validate_mo_list',
#  '_validate_nel',
#  'from_active_indices',
#  'from_dict',
#  'merge_with',
#  'mo_coeff',
#  'mo_list',
#  'nel',
#  'norb',
#  'to_active_indices',
#  'to_dict']

# %%
for k,v in sorted(struc_size.items(),key=lambda x: x[1]):
    print(k)
    # mol = Mole(atom=k, basis="def2-SVP", charge=2, spin=2, verbose=logger.INFO).build()
# Out:
# 19.xyz
# 18.xyz
# 17.xyz
# 16.xyz
# 26.xyz
# 6.xyz
# 1.xyz
# 29.xyz
# 7.xyz
# 4.xyz
# 8.xyz
# 2.xyz
# 9.xyz
# 5.xyz
# 10.xyz
# 20.xyz
# 3.xyz
# 21.xyz
# 15.xyz
# 37.xyz
# 36.xyz
# 12.xyz
# 13.xyz
# 11.xyz
# 22.xyz
# 14.xyz
# 23.xyz
# 35.xyz
# 39.xyz
# 24.xyz
# 40.xyz
# 25.xyz
# 27.xyz
# 38.xyz
# 28.xyz
# 30.xyz
# 31.xyz
# 32.xyz
# 34.xyz
# dk21_hklf4_tw1.xyz
# 33.xyz
# 44.xyz
# 42.xyz
# 49.xyz
# 48.xyz
# 43.xyz
# 50.xyz
# 41.xyz
# 45.xyz
# 47.xyz
# 46.xyz
# 212-mm10_sq.xyz
# QBPA_NCCH3.xyz
# schin15074.xyz
# mo_tkp160419_0m_a.xyz
# twoz_a.xyz
# 2_CCDC1.xyz
# BQPA_NCCH3.xyz
# mo_18004_0m.xyz
# 07217a.xyz
# N2Py2Q.xyz
# 202_1.xyz
# TQA_NCCH3.xyz
# 1-O.xyz
# 09092b.xyz
# gordon_JACs_2021.xyz
